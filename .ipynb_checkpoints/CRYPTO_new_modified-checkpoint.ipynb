# %% [markdown]
# ### Osifo Ernest Osayawe  (Osifo.e@gmail.com) ###
#
# ### Ritabrata Bhattacharyya (ritabrata.bhattacharyya@wqu.org) ###
# **Date:5 MARCH 2020**
#
#
#
# ### CRYPTOCURRENCY TRADING-PAIR FORECASTING, USING MACHINE LEARNING AND DEEP LEARNING TECHNIQUE. ###
#
#
# **1. SELECTION OF PAIR CRYPTOCURRENCIES**
#
# In this research, we attempt to forecast cryptocurrency price and design a strategy that will advantage of the statistical arbitrage via paired crypto-currency trading.
# Our task is divided into the following three major steps
#
#
# *1.Get the Pair currencies; Find the most correlated cryptocurrency to our base Currency (Bitcoin)*
#
# *2.Forecast Adjusted price for selected pair*
#
# *3.Develop a proposed trading strategy*

# %% [markdown]
# ***GETTING THE PAIR CURRENCIES***

# %%
#import packages
import pandas as pd
import numpy as np
import glob,os
import matplotlib.dates as mdates

#to plot within notebook
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sn

#to set seed
np.random.seed(0) # for reproducibility

from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_acf
from pandas import read_csv
from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_pacf
import statsmodels.tsa.stattools as ts 
from statsmodels.tsa.vector_ar.vecm import coint_johansen
#setting figure size
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 20,10

#importing required libraries for Forecasting 
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM

# from pmdarima.arima import auto_arima
#for normalizing data
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range=(0, 1))

#for cointegration test 
from statsmodels.tsa.stattools import coint

import scipy


#read the file
import pandas_datareader as pdr
from datetime import datetime
import statsmodels.regression.linear_model as rg
# import arch.unitroot as at
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12312/996907320.py in <module>
#      25
#      26 #importing required libraries for Forecasting
# ---> 27 from keras.models import Sequential
#      28 from keras.layers import Dense, Dropout, LSTM
#      29
#
# ModuleNotFoundError: No module named 'keras'

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# data_train = pd.read_excel('/content/data_1906-2105.xlsx',index_col=0)
# data_test = pd.read_excel('/content/data_2106-2111.xlsx',index_col=0)
data_train = pd.read_excel(r'C:\Users\Admin\Desktop\2021Fall\MATH 5300 HF\research\data\data_1906-2105.xlsx')
data_test  = pd.read_excel(r'C:\Users\Admin\Desktop\2021Fall\MATH 5300 HF\research\data\data_2106-2111.xlsx')

# %%
data_train.head()
# Out:
#                ADAUSDT  BATUSDT  BTCUSDT  ...  XLMUSDT  XMRUSDT  XRPUSDT
# Time                                      ...
# 1559347200000  0.09022   0.3506  8585.99  ...  0.13455    93.83  0.44145
# 1559350800000  0.08945   0.3480  8567.58  ...  0.13355    93.48  0.43855
# 1559354400000  0.09004   0.3487  8555.00  ...  0.13389    93.36  0.43840
# 1559358000000  0.08960   0.3491  8552.75  ...  0.13292    93.11  0.43638
# 1559361600000  0.08950   0.3493  8561.23  ...  0.13329    93.07  0.43905
#
# [5 rows x 22 columns]

# %%
data_train.index = pd.to_datetime(data_train.index, unit='ms')
data_train = data_train[~data_train.index.duplicated(keep='first')]
data_train = data_train.resample('60T').pad()

# %%
data_test.index = pd.to_datetime(data_test.index, unit='ms')
data_test = data_test[~data_test.index.duplicated(keep='first')]
data_test = data_test.resample('60T').pad()

# %%
data_train.head()
# Out:
#                      ADAUSDT  BATUSDT  BTCUSDT  ...  XLMUSDT  XMRUSDT  XRPUSDT
# Time                                            ...
# 2019-06-01 00:00:00  0.09022   0.3506  8585.99  ...  0.13455    93.83  0.44145
# 2019-06-01 01:00:00  0.08945   0.3480  8567.58  ...  0.13355    93.48  0.43855
# 2019-06-01 02:00:00  0.09004   0.3487  8555.00  ...  0.13389    93.36  0.43840
# 2019-06-01 03:00:00  0.08960   0.3491  8552.75  ...  0.13292    93.11  0.43638
# 2019-06-01 04:00:00  0.08950   0.3493  8561.23  ...  0.13329    93.07  0.43905
#
# [5 rows x 22 columns]

# %%
data_train.shape
# Out:
# (17544, 22)

# %%
data_test.head()
# Out:
#                      ADAUSDT  BATUSDT   BTCUSDT  ...  XLMUSDT  XMRUSDT  XRPUSDT
# Time                                             ...
# 2021-06-01 00:00:00   1.7719   0.7736  37798.31  ...  0.41358   273.70   1.0891
# 2021-06-01 01:00:00   1.7243   0.7535  37196.64  ...  0.40057   267.14   1.0576
# 2021-06-01 02:00:00   1.7136   0.7540  36850.00  ...  0.40213   271.48   1.0451
# 2021-06-01 03:00:00   1.7117   0.7478  36704.99  ...  0.39629   268.11   1.0364
# 2021-06-01 04:00:00   1.7248   0.7530  36748.01  ...  0.39752   269.99   1.0429
#
# [5 rows x 22 columns]

# %%
data_test.shape
# Out:
# (4392, 22)

# %% [markdown]
# Concatenating the adjusted Close for the **nine Crypto-currencies**

# %% [markdown]
# *we then visulized the Performance of the Cryptocurrencies*

# %%
#1.1.2 Normalize prices by first value
assets = data_train.columns.to_list()
norm_prices = data_train.divide(data_train.iloc[0])

plt.figure(figsize=(16,8))
plt.rcParams.update({'font.size':10})
plt.xticks(rotation=45)
ax = plt.axes()
ax.xaxis.set_major_locator(plt.MaxNLocator(20))
plt.plot(norm_prices)
plt.title('Performance of cryptocurrencies')
plt.legend(assets)
plt.xlabel("Date")
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax.grid(True)

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %% [markdown]
# we observed that some of the currencies tend to out perform others within the reviewed period,
#
# Then *we then introduce the percentage change to our data so as to scale them*

# %%
#1.1.3 Normalizing the datafrme  
data=pd.DataFrame(data_train)

def normalize_series(data):
    #take tail to drop head NA
    return data.pct_change(1).dropna()
dt=normalize_series(data)
dt.head()
# Out:
#                       ADAUSDT   BATUSDT   BTCUSDT  ...   XLMUSDT   XMRUSDT   XRPUSDT
# Time                                               ...
# 2019-06-01 01:00:00 -0.008535 -0.007416 -0.002144  ... -0.007432 -0.003730 -0.006569
# 2019-06-01 02:00:00  0.006596  0.002011 -0.001468  ...  0.002546 -0.001284 -0.000342
# 2019-06-01 03:00:00 -0.004887  0.001147 -0.000263  ... -0.007245 -0.002678 -0.004608
# 2019-06-01 04:00:00 -0.001116  0.000573  0.000991  ...  0.002784 -0.000430  0.006119
# 2019-06-01 05:00:00 -0.024022 -0.015746 -0.009923  ... -0.017256 -0.014935 -0.018198
#
# [5 rows x 22 columns]

# %%
#1.1.4 Normalizing and setting up cumulative returns in a  datafrme 
def normalize_and_accumulate_series(data):
    #take tail to drop head NA
    return data.pct_change(1).cumsum().dropna()
dtc =normalize_and_accumulate_series(data)
dtc.head()
# Out:
#                       ADAUSDT   BATUSDT   BTCUSDT  ...   XLMUSDT   XMRUSDT   XRPUSDT
# Time                                               ...
# 2019-06-01 01:00:00 -0.008535 -0.007416 -0.002144  ... -0.007432 -0.003730 -0.006569
# 2019-06-01 02:00:00 -0.001939 -0.005404 -0.003613  ... -0.004886 -0.005014 -0.006911
# 2019-06-01 03:00:00 -0.006826 -0.004257 -0.003876  ... -0.012131 -0.007692 -0.011519
# 2019-06-01 04:00:00 -0.007942 -0.003684 -0.002884  ... -0.009347 -0.008121 -0.005400
# 2019-06-01 05:00:00 -0.031964 -0.019430 -0.012807  ... -0.026603 -0.023056 -0.023599
#
# [5 rows x 22 columns]

# %% [markdown]
# we also examined the Cummulative percentage change for each Crypto-Currency

# %% [markdown]
# THE PERCENTAGE CHANGE PLOT

# %%
#1.1.5 the Percentage change plot 

plt.figure(figsize=(16,8))
plt.rcParams.update({'font.size':10})
plt.xticks(rotation=45)
ax = plt.axes()
ax.xaxis.set_major_locator(plt.MaxNLocator(20))
plt.plot(dt)
plt.xlabel("Date")
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))

ax.grid(True)
plt.legend(assets, loc='best')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %% [markdown]
# THE CUMMULATIVE RETURNS PLOT

# %%
#1.1.6 the Cummulative returns Plot

plt.figure(figsize=(16,8))
plt.rcParams.update({'font.size':10})
plt.xticks(rotation=45)
ax = plt.axes()
ax.xaxis.set_major_locator(plt.MaxNLocator(20))
plt.plot(dtc)
plt.xlabel("Date")
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
ax.grid(True)
plt.legend(assets, loc='best')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.

# %% [markdown]
# Two major criteria that would determine the desired pair are the correlation value and Cointegration. The pair with the highest correlation, is the desired pair. High positive correlation indicates that the returns of both currencies are trending in same direction. Additionally, the cointegration of the same pair should be significantly low. A value lower than 0.05 is desired

# %% [markdown]
# First we attempted to get the p-value of all possible pair in our selected (9- Crypto currency Universe)

# %%
#1.1.7 obtaining the cointegration test P-value for every possible pair (for whole available time horizons)
coint_mat = []
for a1 in assets:
  coint_one = []
  for a2 in assets:
    test_result = ts.coint(data[a1], data[a2])
    coint_one.append(test_result[1])
    print(a1 + ' and ' + a2 + ': p-value = ' + str(test_result[1]))
  coint_mat.append(coint_one)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py:1432: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   .. [1] https://en.wikipedia.org/wiki/Granger_causality
# ADAUSDT and ADAUSDT: p-value = 0.0
# ADAUSDT and BATUSDT: p-value = 0.8133682892597471
# ADAUSDT and BTCUSDT: p-value = 0.9364405600835302
# ADAUSDT and BTTUSDT: p-value = 0.3837552447105169
# ADAUSDT and DASHUSDT: p-value = 0.24588606397216933
# ADAUSDT and EOSUSDT: p-value = 0.48697330384594106
# ADAUSDT and ETCUSDT: p-value = 0.09084553737318762
# ADAUSDT and ETHUSDT: p-value = 0.012668518698766422
# ADAUSDT and HOTUSDT: p-value = 0.4676784625893372
# ADAUSDT and IOTAUSDT: p-value = 0.8417777118768112
# ADAUSDT and LINKUSDT: p-value = 0.5042505768603633
# ADAUSDT and LTCUSDT: p-value = 0.5780127247156177
# ADAUSDT and NEOUSDT: p-value = 0.17625054936450812
# ADAUSDT and OMGUSDT: p-value = 0.41201160689124744
# ADAUSDT and QTUMUSDT: p-value = 0.05372082507340778
# ADAUSDT and THETAUSDT: p-value = 0.261255801858568
# ADAUSDT and TRXUSDT: p-value = 0.4379584506112787
# ADAUSDT and TRXUSDT.1: p-value = 0.24168701946005305
# ADAUSDT and VETUSDT: p-value = 0.24168701946005305
# ADAUSDT and XLMUSDT: p-value = 0.6996694534343838
# ADAUSDT and XMRUSDT: p-value = 0.5166500505918167
# ADAUSDT and XRPUSDT: p-value = 0.3032120481546835
# BATUSDT and ADAUSDT: p-value = 0.43161317488844525
# BATUSDT and BATUSDT: p-value = 0.0
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py:1432: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   .. [1] https://en.wikipedia.org/wiki/Granger_causality
# BATUSDT and BTCUSDT: p-value = 0.20644574199504195
# BATUSDT and BTTUSDT: p-value = 3.805249930274681e-05
# BATUSDT and DASHUSDT: p-value = 0.018511284605832203
# BATUSDT and EOSUSDT: p-value = 0.13387008013739782
# BATUSDT and ETCUSDT: p-value = 0.4237883623226516
# BATUSDT and ETHUSDT: p-value = 0.22150587063828303
# BATUSDT and HOTUSDT: p-value = 1.5021918872756825e-05
# BATUSDT and IOTAUSDT: p-value = 0.00022476544338400473
# BATUSDT and LINKUSDT: p-value = 0.20994077503142017
# BATUSDT and LTCUSDT: p-value = 0.17160090398889166
# BATUSDT and NEOUSDT: p-value = 0.005825017864829964
# BATUSDT and OMGUSDT: p-value = 0.22779836565748357
# BATUSDT and QTUMUSDT: p-value = 0.003624012844310203
# BATUSDT and THETAUSDT: p-value = 7.936081252222988e-07
# BATUSDT and TRXUSDT: p-value = 0.0005115654983088126
# BATUSDT and TRXUSDT.1: p-value = 0.01819809645055777
# BATUSDT and VETUSDT: p-value = 0.01819809645055777
# BATUSDT and XLMUSDT: p-value = 0.15216319892757268
# BATUSDT and XMRUSDT: p-value = 0.0737570296048967
# BATUSDT and XRPUSDT: p-value = 0.05453171037722879
# BTCUSDT and ADAUSDT: p-value = 0.8261184851800585
# BTCUSDT and BATUSDT: p-value = 0.28486023298205193
# BTCUSDT and BTCUSDT: p-value = 0.0
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py:1432: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   .. [1] https://en.wikipedia.org/wiki/Granger_causality
# BTCUSDT and BTTUSDT: p-value = 0.35984693047382366
# BTCUSDT and DASHUSDT: p-value = 0.09901072528591981
# BTCUSDT and EOSUSDT: p-value = 0.40030115699523966
# BTCUSDT and ETCUSDT: p-value = 0.648334527630487
# BTCUSDT and ETHUSDT: p-value = 0.888821410701409
# BTCUSDT and HOTUSDT: p-value = 0.35124624687783873
# BTCUSDT and IOTAUSDT: p-value = 0.24775092160619017
# BTCUSDT and LINKUSDT: p-value = 0.2169784738290993
# BTCUSDT and LTCUSDT: p-value = 0.15007316297212803
# BTCUSDT and NEOUSDT: p-value = 0.3693638932581601
# BTCUSDT and OMGUSDT: p-value = 0.17954837590996986
# BTCUSDT and QTUMUSDT: p-value = 0.3412446665705645
# BTCUSDT and THETAUSDT: p-value = 0.3496000872888139
# BTCUSDT and TRXUSDT: p-value = 0.2795384669123543
# BTCUSDT and TRXUSDT.1: p-value = 0.6215201577395671
# BTCUSDT and VETUSDT: p-value = 0.6215201577395671
# BTCUSDT and XLMUSDT: p-value = 0.005334446928838393
# BTCUSDT and XMRUSDT: p-value = 0.38871328285279966
# BTCUSDT and XRPUSDT: p-value = 0.4301817780882916
# BTTUSDT and ADAUSDT: p-value = 0.06778245809510541
# BTTUSDT and BATUSDT: p-value = 2.5594674074582497e-05
# BTTUSDT and BTCUSDT: p-value = 0.18083671139016788
# BTTUSDT and BTTUSDT: p-value = 0.0
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py:1432: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   .. [1] https://en.wikipedia.org/wiki/Granger_causality
# BTTUSDT and DASHUSDT: p-value = 0.026220303523041485
# BTTUSDT and EOSUSDT: p-value = 0.03327980965025597
# BTTUSDT and ETCUSDT: p-value = 0.1467071859455218
# BTTUSDT and ETHUSDT: p-value = 0.06036968989037391
# BTTUSDT and HOTUSDT: p-value = 3.170221063587459e-07
# BTTUSDT and IOTAUSDT: p-value = 0.005928201513629766
# BTTUSDT and LINKUSDT: p-value = 0.14228440003301585
# BTTUSDT and LTCUSDT: p-value = 0.060950397583504866
# BTTUSDT and NEOUSDT: p-value = 0.0042064380596821644
# BTTUSDT and OMGUSDT: p-value = 0.0745837566105596
# BTTUSDT and QTUMUSDT: p-value = 7.033781317563685e-05
# BTTUSDT and THETAUSDT: p-value = 0.00022654470752608434
# BTTUSDT and TRXUSDT: p-value = 0.01862814096491042
# BTTUSDT and TRXUSDT.1: p-value = 0.0007899809817953206
# BTTUSDT and VETUSDT: p-value = 0.0007899809817953206
# BTTUSDT and XLMUSDT: p-value = 0.08628451559545963
# BTTUSDT and XMRUSDT: p-value = 0.02839535573834892
# BTTUSDT and XRPUSDT: p-value = 0.00011201831253318928
# DASHUSDT and ADAUSDT: p-value = 0.05423290225861575
# DASHUSDT and BATUSDT: p-value = 0.009066456088854999
# DASHUSDT and BTCUSDT: p-value = 0.0312661052200548
# DASHUSDT and BTTUSDT: p-value = 0.018136638041980763
# DASHUSDT and DASHUSDT: p-value = 0.0
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py:1432: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   .. [1] https://en.wikipedia.org/wiki/Granger_causality
# DASHUSDT and EOSUSDT: p-value = 0.050417411261495244
# DASHUSDT and ETCUSDT: p-value = 0.4195843617617575
# DASHUSDT and ETHUSDT: p-value = 0.06214008075486463
# DASHUSDT and HOTUSDT: p-value = 0.032452789658299126
# DASHUSDT and IOTAUSDT: p-value = 0.0004020751577578156
# DASHUSDT and LINKUSDT: p-value = 0.07923959906299816
# DASHUSDT and LTCUSDT: p-value = 0.0027654025075180555
# DASHUSDT and NEOUSDT: p-value = 0.004656774013808605
# DASHUSDT and OMGUSDT: p-value = 0.1109597496843896
# DASHUSDT and QTUMUSDT: p-value = 0.0007842747069316169
# DASHUSDT and THETAUSDT: p-value = 0.014252519557693275
# DASHUSDT and TRXUSDT: p-value = 0.03128092847856209
# DASHUSDT and TRXUSDT.1: p-value = 0.021272631231806366
# DASHUSDT and VETUSDT: p-value = 0.021272631231806366
# DASHUSDT and XLMUSDT: p-value = 0.008898782561810106
# DASHUSDT and XMRUSDT: p-value = 0.01816725100533653
# DASHUSDT and XRPUSDT: p-value = 0.010862951796371464
# EOSUSDT and ADAUSDT: p-value = 0.004067692728964897
# EOSUSDT and BATUSDT: p-value = 0.007853101054147864
# EOSUSDT and BTCUSDT: p-value = 0.025419148092172612
# EOSUSDT and BTTUSDT: p-value = 0.0021040431865841664
# EOSUSDT and DASHUSDT: p-value = 0.005758742099830605
# EOSUSDT and EOSUSDT: p-value = 0.0
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py:1432: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   .. [1] https://en.wikipedia.org/wiki/Granger_causality
# EOSUSDT and ETCUSDT: p-value = 0.0028390176000672187
# EOSUSDT and ETHUSDT: p-value = 0.0033176547593696273
# EOSUSDT and HOTUSDT: p-value = 0.004971973729983058
# EOSUSDT and IOTAUSDT: p-value = 0.006917341217552196
# EOSUSDT and LINKUSDT: p-value = 0.016259956285970004
# EOSUSDT and LTCUSDT: p-value = 0.0045141811499375805
# EOSUSDT and NEOUSDT: p-value = 0.0018607430738776418
# EOSUSDT and OMGUSDT: p-value = 0.02441596573864008
# EOSUSDT and QTUMUSDT: p-value = 0.0002726857798223904
# EOSUSDT and THETAUSDT: p-value = 0.0061640534710152226
# EOSUSDT and TRXUSDT: p-value = 0.004901921263029931
# EOSUSDT and TRXUSDT.1: p-value = 0.002122021135319101
# EOSUSDT and VETUSDT: p-value = 0.002122021135319101
# EOSUSDT and XLMUSDT: p-value = 0.014930974342286768
# EOSUSDT and XMRUSDT: p-value = 0.004599502951008159
# EOSUSDT and XRPUSDT: p-value = 0.00079239502227953
# ETCUSDT and ADAUSDT: p-value = 0.014675227134829414
# ETCUSDT and BATUSDT: p-value = 0.3982768963726963
# ETCUSDT and BTCUSDT: p-value = 0.43447645028764437
# ETCUSDT and BTTUSDT: p-value = 0.19577665287746215
# ETCUSDT and DASHUSDT: p-value = 0.5981141396674752
# ETCUSDT and EOSUSDT: p-value = 0.1040508125405174
# ETCUSDT and ETCUSDT: p-value = 0.0
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py:1432: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   .. [1] https://en.wikipedia.org/wiki/Granger_causality
# ETCUSDT and ETHUSDT: p-value = 0.004786032136457003
# ETCUSDT and HOTUSDT: p-value = 0.2183836209700088
# ETCUSDT and IOTAUSDT: p-value = 0.33249023967390656
# ETCUSDT and LINKUSDT: p-value = 0.25361999914596184
# ETCUSDT and LTCUSDT: p-value = 0.4411637987989267
# ETCUSDT and NEOUSDT: p-value = 0.1153095426149306
# ETCUSDT and OMGUSDT: p-value = 0.6021438015766164
# ETCUSDT and QTUMUSDT: p-value = 0.2814810175409013
# ETCUSDT and THETAUSDT: p-value = 0.22669823602155076
# ETCUSDT and TRXUSDT: p-value = 0.24029952827078238
# ETCUSDT and TRXUSDT.1: p-value = 0.08549196238692741
# ETCUSDT and VETUSDT: p-value = 0.08549196238692741
# ETCUSDT and XLMUSDT: p-value = 0.3191885495174208
# ETCUSDT and XMRUSDT: p-value = 0.13444988303817457
# ETCUSDT and XRPUSDT: p-value = 0.0031618692950566287
# ETHUSDT and ADAUSDT: p-value = 0.007617695349754831
# ETHUSDT and BATUSDT: p-value = 0.5376165290988691
# ETHUSDT and BTCUSDT: p-value = 0.9496361064550287
# ETHUSDT and BTTUSDT: p-value = 0.27057748030917395
# ETHUSDT and DASHUSDT: p-value = 0.3463305585450954
# ETHUSDT and EOSUSDT: p-value = 0.26985060112542253
# ETHUSDT and ETCUSDT: p-value = 0.016508564272384715
# ETHUSDT and ETHUSDT: p-value = 0.0
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py:1432: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   .. [1] https://en.wikipedia.org/wiki/Granger_causality
# ETHUSDT and HOTUSDT: p-value = 0.49592861545277495
# ETHUSDT and IOTAUSDT: p-value = 0.675096804578122
# ETHUSDT and LINKUSDT: p-value = 0.48152092899462096
# ETHUSDT and LTCUSDT: p-value = 0.690595743187175
# ETHUSDT and NEOUSDT: p-value = 0.017827483793979814
# ETHUSDT and OMGUSDT: p-value = 0.21183643869664887
# ETHUSDT and QTUMUSDT: p-value = 0.007944873003408112
# ETHUSDT and THETAUSDT: p-value = 0.3368635405190482
# ETHUSDT and TRXUSDT: p-value = 0.11397238477179661
# ETHUSDT and TRXUSDT.1: p-value = 0.1594002558070161
# ETHUSDT and VETUSDT: p-value = 0.1594002558070161
# ETHUSDT and XLMUSDT: p-value = 0.022123185568427513
# ETHUSDT and XMRUSDT: p-value = 0.04814937167244115
# ETHUSDT and XRPUSDT: p-value = 0.04393037660064601
# HOTUSDT and ADAUSDT: p-value = 0.09019944766149401
# HOTUSDT and BATUSDT: p-value = 9.563137777134238e-06
# HOTUSDT and BTCUSDT: p-value = 0.17592743315033282
# HOTUSDT and BTTUSDT: p-value = 2.510184816151895e-07
# HOTUSDT and DASHUSDT: p-value = 0.04549316974672091
# HOTUSDT and EOSUSDT: p-value = 0.06874823566922877
# HOTUSDT and ETCUSDT: p-value = 0.14754318223334617
# HOTUSDT and ETHUSDT: p-value = 0.13151294781194522
# HOTUSDT and HOTUSDT: p-value = 0.0
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py:1432: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   .. [1] https://en.wikipedia.org/wiki/Granger_causality
# HOTUSDT and IOTAUSDT: p-value = 0.007073953204965279
# HOTUSDT and LINKUSDT: p-value = 0.17803154733267557
# HOTUSDT and LTCUSDT: p-value = 0.07585648250171197
# HOTUSDT and NEOUSDT: p-value = 0.024270011668366457
# HOTUSDT and OMGUSDT: p-value = 0.07296124368248491
# HOTUSDT and QTUMUSDT: p-value = 0.0021506025968195423
# HOTUSDT and THETAUSDT: p-value = 7.515149278026954e-05
# HOTUSDT and TRXUSDT: p-value = 0.015401631466962412
# HOTUSDT and TRXUSDT.1: p-value = 0.006151668584363902
# HOTUSDT and VETUSDT: p-value = 0.006151668584363902
# HOTUSDT and XLMUSDT: p-value = 0.07758664187548357
# HOTUSDT and XMRUSDT: p-value = 0.044527082210095936
# HOTUSDT and XRPUSDT: p-value = 0.003215625986259832
# IOTAUSDT and ADAUSDT: p-value = 0.6067897695071957
# IOTAUSDT and BATUSDT: p-value = 0.0002886968473127496
# IOTAUSDT and BTCUSDT: p-value = 0.19534587333307107
# IOTAUSDT and BTTUSDT: p-value = 0.01142131631046525
# IOTAUSDT and DASHUSDT: p-value = 0.0012312905213362878
# IOTAUSDT and EOSUSDT: p-value = 0.12923515706197197
# IOTAUSDT and ETCUSDT: p-value = 0.4727257925918279
# IOTAUSDT and ETHUSDT: p-value = 0.41796894839412957
# IOTAUSDT and HOTUSDT: p-value = 0.014732668983178617
# IOTAUSDT and IOTAUSDT: p-value = 0.0
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py:1432: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   .. [1] https://en.wikipedia.org/wiki/Granger_causality
# IOTAUSDT and LINKUSDT: p-value = 0.22216405540559625
# IOTAUSDT and LTCUSDT: p-value = 0.13110279495821064
# IOTAUSDT and NEOUSDT: p-value = 0.012752823805459699
# IOTAUSDT and OMGUSDT: p-value = 0.14360188484542913
# IOTAUSDT and QTUMUSDT: p-value = 0.019345728305010527
# IOTAUSDT and THETAUSDT: p-value = 0.02992831899050863
# IOTAUSDT and TRXUSDT: p-value = 0.0051489293876855685
# IOTAUSDT and TRXUSDT.1: p-value = 0.1641436642628507
# IOTAUSDT and VETUSDT: p-value = 0.1641436642628507
# IOTAUSDT and XLMUSDT: p-value = 0.09457164602941648
# IOTAUSDT and XMRUSDT: p-value = 0.11169087836015407
# IOTAUSDT and XRPUSDT: p-value = 0.10306487151714006
# LINKUSDT and ADAUSDT: p-value = 0.2041824790467977
# LINKUSDT and BATUSDT: p-value = 0.28756596341716206
# LINKUSDT and BTCUSDT: p-value = 0.20068507562487486
# LINKUSDT and BTTUSDT: p-value = 0.25662942960673574
# LINKUSDT and DASHUSDT: p-value = 0.22412253919851277
# LINKUSDT and EOSUSDT: p-value = 0.32780483988452597
# LINKUSDT and ETCUSDT: p-value = 0.35334361784953583
# LINKUSDT and ETHUSDT: p-value = 0.2615230642258931
# LINKUSDT and HOTUSDT: p-value = 0.3268766327758254
# LINKUSDT and IOTAUSDT: p-value = 0.25418813997522094
# LINKUSDT and LINKUSDT: p-value = 0.0
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py:1432: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   .. [1] https://en.wikipedia.org/wiki/Granger_causality
# LINKUSDT and LTCUSDT: p-value = 0.3229951704635073
# LINKUSDT and NEOUSDT: p-value = 0.09989378235126756
# LINKUSDT and OMGUSDT: p-value = 0.0014969924730353224
# LINKUSDT and QTUMUSDT: p-value = 0.08170883661493289
# LINKUSDT and THETAUSDT: p-value = 0.19334125755878412
# LINKUSDT and TRXUSDT: p-value = 0.10455163760189662
# LINKUSDT and TRXUSDT.1: p-value = 0.25289744287769234
# LINKUSDT and VETUSDT: p-value = 0.25289744287769234
# LINKUSDT and XLMUSDT: p-value = 0.006362726851156612
# LINKUSDT and XMRUSDT: p-value = 0.005202544266517203
# LINKUSDT and XRPUSDT: p-value = 0.18801944838988682
# LTCUSDT and ADAUSDT: p-value = 0.22434852356696444
# LTCUSDT and BATUSDT: p-value = 0.1874726750477858
# LTCUSDT and BTCUSDT: p-value = 0.10542009415272469
# LTCUSDT and BTTUSDT: p-value = 0.10841042590846678
# LTCUSDT and DASHUSDT: p-value = 0.006296169437695711
# LTCUSDT and EOSUSDT: p-value = 0.08385766879820411
# LTCUSDT and ETCUSDT: p-value = 0.5015713112327117
# LTCUSDT and ETHUSDT: p-value = 0.38200048110744833
# LTCUSDT and HOTUSDT: p-value = 0.12336108736970403
# LTCUSDT and IOTAUSDT: p-value = 0.11515378502120677
# LTCUSDT and LINKUSDT: p-value = 0.2251355053732042
# LTCUSDT and LTCUSDT: p-value = 0.0
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py:1432: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   .. [1] https://en.wikipedia.org/wiki/Granger_causality
# LTCUSDT and NEOUSDT: p-value = 0.03809799420813673
# LTCUSDT and OMGUSDT: p-value = 0.2044212082622684
# LTCUSDT and QTUMUSDT: p-value = 0.02306092529047375
# LTCUSDT and THETAUSDT: p-value = 0.11229138355319229
# LTCUSDT and TRXUSDT: p-value = 0.06181988033379035
# LTCUSDT and TRXUSDT.1: p-value = 0.15758016200696862
# LTCUSDT and VETUSDT: p-value = 0.15758016200696862
# LTCUSDT and XLMUSDT: p-value = 0.008491048785447803
# LTCUSDT and XMRUSDT: p-value = 0.016979112806606644
# LTCUSDT and XRPUSDT: p-value = 0.0642941856683486
# NEOUSDT and ADAUSDT: p-value = 0.04679571931797024
# NEOUSDT and BATUSDT: p-value = 0.007058068777739947
# NEOUSDT and BTCUSDT: p-value = 0.29107408899374454
# NEOUSDT and BTTUSDT: p-value = 0.007148786069254349
# NEOUSDT and DASHUSDT: p-value = 0.012301590893619072
# NEOUSDT and EOSUSDT: p-value = 0.040560056217562916
# NEOUSDT and ETCUSDT: p-value = 0.1529138921027815
# NEOUSDT and ETHUSDT: p-value = 0.005441017286681833
# NEOUSDT and HOTUSDT: p-value = 0.038083901003193754
# NEOUSDT and IOTAUSDT: p-value = 0.011203843128196217
# NEOUSDT and LINKUSDT: p-value = 0.07668383855311078
# NEOUSDT and LTCUSDT: p-value = 0.039078335804896565
# NEOUSDT and NEOUSDT: p-value = 0.0
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py:1432: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   .. [1] https://en.wikipedia.org/wiki/Granger_causality
# NEOUSDT and OMGUSDT: p-value = 0.0284171092965731
# NEOUSDT and QTUMUSDT: p-value = 9.273740357430207e-05
# NEOUSDT and THETAUSDT: p-value = 0.018655197119755877
# NEOUSDT and TRXUSDT: p-value = 2.983380601363263e-08
# NEOUSDT and TRXUSDT.1: p-value = 0.004108539510248834
# NEOUSDT and VETUSDT: p-value = 0.004108539510248834
# NEOUSDT and XLMUSDT: p-value = 0.03277075794427384
# NEOUSDT and XMRUSDT: p-value = 0.00021608044256985783
# NEOUSDT and XRPUSDT: p-value = 1.9411837911814963e-05
# OMGUSDT and ADAUSDT: p-value = 0.0866213690223454
# OMGUSDT and BATUSDT: p-value = 0.19152625274242768
# OMGUSDT and BTCUSDT: p-value = 0.0901322586548084
# OMGUSDT and BTTUSDT: p-value = 0.07870187281364066
# OMGUSDT and DASHUSDT: p-value = 0.1681524842659245
# OMGUSDT and EOSUSDT: p-value = 0.29768592948042844
# OMGUSDT and ETCUSDT: p-value = 0.5302908219030549
# OMGUSDT and ETHUSDT: p-value = 0.05262506096910549
# OMGUSDT and HOTUSDT: p-value = 0.08087681872713731
# OMGUSDT and IOTAUSDT: p-value = 0.08866897935453372
# OMGUSDT and LINKUSDT: p-value = 0.0007164673770782945
# OMGUSDT and LTCUSDT: p-value = 0.16348854546489439
# OMGUSDT and NEOUSDT: p-value = 0.018660734383518996
# OMGUSDT and OMGUSDT: p-value = 0.0
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py:1432: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   .. [1] https://en.wikipedia.org/wiki/Granger_causality
# OMGUSDT and QTUMUSDT: p-value = 0.16398433054348327
# OMGUSDT and THETAUSDT: p-value = 0.06705948218726451
# OMGUSDT and TRXUSDT: p-value = 0.009133632694075742
# OMGUSDT and TRXUSDT.1: p-value = 0.07699058046521041
# OMGUSDT and VETUSDT: p-value = 0.07699058046521041
# OMGUSDT and XLMUSDT: p-value = 0.05608804367300296
# OMGUSDT and XMRUSDT: p-value = 0.002819809825226398
# OMGUSDT and XRPUSDT: p-value = 0.05444751915975632
# QTUMUSDT and ADAUSDT: p-value = 0.005741217523492892
# QTUMUSDT and BATUSDT: p-value = 0.0020100259475816502
# QTUMUSDT and BTCUSDT: p-value = 0.16276779207747488
# QTUMUSDT and BTTUSDT: p-value = 6.254730758024557e-05
# QTUMUSDT and DASHUSDT: p-value = 0.0014242536383486193
# QTUMUSDT and EOSUSDT: p-value = 0.004887652243866539
# QTUMUSDT and ETCUSDT: p-value = 0.20698882152397569
# QTUMUSDT and ETHUSDT: p-value = 0.001073981812247265
# QTUMUSDT and HOTUSDT: p-value = 0.0018685670757767371
# QTUMUSDT and IOTAUSDT: p-value = 0.010303208920345613
# QTUMUSDT and LINKUSDT: p-value = 0.04012993983980791
# QTUMUSDT and LTCUSDT: p-value = 0.013004251426208232
# QTUMUSDT and NEOUSDT: p-value = 5.9824500599432026e-05
# QTUMUSDT and OMGUSDT: p-value = 0.1575176764781861
# QTUMUSDT and QTUMUSDT: p-value = 0.0
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py:1432: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   .. [1] https://en.wikipedia.org/wiki/Granger_causality
# QTUMUSDT and THETAUSDT: p-value = 0.008689559506788591
# QTUMUSDT and TRXUSDT: p-value = 4.920823001566e-07
# QTUMUSDT and TRXUSDT.1: p-value = 0.00017571065572773915
# QTUMUSDT and VETUSDT: p-value = 0.00017571065572773915
# QTUMUSDT and XLMUSDT: p-value = 0.036513605147401595
# QTUMUSDT and XMRUSDT: p-value = 0.004482354198402254
# QTUMUSDT and XRPUSDT: p-value = 1.7946338682298538e-06
# THETAUSDT and ADAUSDT: p-value = 0.11788812766077278
# THETAUSDT and BATUSDT: p-value = 1.4644973926666335e-06
# THETAUSDT and BTCUSDT: p-value = 0.33285419271153616
# THETAUSDT and BTTUSDT: p-value = 0.0007030294081535698
# THETAUSDT and DASHUSDT: p-value = 0.06054607641535833
# THETAUSDT and EOSUSDT: p-value = 0.16720275573537663
# THETAUSDT and ETCUSDT: p-value = 0.38561734066546693
# THETAUSDT and ETHUSDT: p-value = 0.19050974230320167
# THETAUSDT and HOTUSDT: p-value = 0.00022930864810566265
# THETAUSDT and IOTAUSDT: p-value = 0.03980516064898174
# THETAUSDT and LINKUSDT: p-value = 0.23457870714046053
# THETAUSDT and LTCUSDT: p-value = 0.1711570593538202
# THETAUSDT and NEOUSDT: p-value = 0.028622735874142408
# THETAUSDT and OMGUSDT: p-value = 0.12950550319698861
# THETAUSDT and QTUMUSDT: p-value = 0.02195060819020086
# THETAUSDT and THETAUSDT: p-value = 0.0
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py:1432: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   .. [1] https://en.wikipedia.org/wiki/Granger_causality
# THETAUSDT and TRXUSDT: p-value = 0.00237033749765668
# THETAUSDT and TRXUSDT.1: p-value = 0.06796925326171177
# THETAUSDT and VETUSDT: p-value = 0.06796925326171177
# THETAUSDT and XLMUSDT: p-value = 0.07673511142452819
# THETAUSDT and XMRUSDT: p-value = 0.07593689980515403
# THETAUSDT and XRPUSDT: p-value = 0.07629911951436556
# TRXUSDT and ADAUSDT: p-value = 0.11731695655427471
# TRXUSDT and BATUSDT: p-value = 0.0004909394516883298
# TRXUSDT and BTCUSDT: p-value = 0.18338739150341388
# TRXUSDT and BTTUSDT: p-value = 0.027752257328117837
# TRXUSDT and DASHUSDT: p-value = 0.05625293816058463
# TRXUSDT and EOSUSDT: p-value = 0.09589833920924029
# TRXUSDT and ETCUSDT: p-value = 0.24294636721373386
# TRXUSDT and ETHUSDT: p-value = 0.030735435898523886
# TRXUSDT and HOTUSDT: p-value = 0.021851512283529616
# TRXUSDT and IOTAUSDT: p-value = 0.00362940346929272
# TRXUSDT and LINKUSDT: p-value = 0.06539453535163087
# TRXUSDT and LTCUSDT: p-value = 0.05554781912753719
# TRXUSDT and NEOUSDT: p-value = 2.2379138979442847e-08
# TRXUSDT and OMGUSDT: p-value = 0.011115923249935124
# TRXUSDT and QTUMUSDT: p-value = 8.175665269181134e-07
# TRXUSDT and THETAUSDT: p-value = 0.0011923752987953017
# TRXUSDT and TRXUSDT: p-value = 0.0
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py:1432: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   .. [1] https://en.wikipedia.org/wiki/Granger_causality
# TRXUSDT and TRXUSDT.1: p-value = 4.0364395089219263e-05
# TRXUSDT and VETUSDT: p-value = 4.0364395089219263e-05
# TRXUSDT and XLMUSDT: p-value = 0.08476314824404052
# TRXUSDT and XMRUSDT: p-value = 0.000979137025635566
# TRXUSDT and XRPUSDT: p-value = 7.471624300927903e-05
# TRXUSDT.1 and ADAUSDT: p-value = 0.10020543422857708
# TRXUSDT.1 and BATUSDT: p-value = 0.03632538631744091
# TRXUSDT.1 and BTCUSDT: p-value = 0.656311266636102
# TRXUSDT.1 and BTTUSDT: p-value = 0.0024365344935029926
# TRXUSDT.1 and DASHUSDT: p-value = 0.08700164788103615
# TRXUSDT.1 and EOSUSDT: p-value = 0.09287096638118114
# TRXUSDT.1 and ETCUSDT: p-value = 0.1569821018521914
# TRXUSDT.1 and ETHUSDT: p-value = 0.08687839733207503
# TRXUSDT.1 and HOTUSDT: p-value = 0.016112778593991565
# TRXUSDT.1 and IOTAUSDT: p-value = 0.23632942124268713
# TRXUSDT.1 and LINKUSDT: p-value = 0.3071940153436565
# TRXUSDT.1 and LTCUSDT: p-value = 0.260683267393226
# TRXUSDT.1 and NEOUSDT: p-value = 0.006866787109072155
# TRXUSDT.1 and OMGUSDT: p-value = 0.17932129162656307
# TRXUSDT.1 and QTUMUSDT: p-value = 0.0005311840961136502
# TRXUSDT.1 and THETAUSDT: p-value = 0.06868025572033577
# TRXUSDT.1 and TRXUSDT: p-value = 9.748104804135583e-05
# TRXUSDT.1 and TRXUSDT.1: p-value = 0.0
# TRXUSDT.1 and VETUSDT: p-value = 0.0
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py:1432: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   .. [1] https://en.wikipedia.org/wiki/Granger_causality
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py:1432: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   .. [1] https://en.wikipedia.org/wiki/Granger_causality
# TRXUSDT.1 and XLMUSDT: p-value = 0.19682325982510251
# TRXUSDT.1 and XMRUSDT: p-value = 0.031455465792729766
# TRXUSDT.1 and XRPUSDT: p-value = 4.383628968054698e-05
# VETUSDT and ADAUSDT: p-value = 0.10020543422857708
# VETUSDT and BATUSDT: p-value = 0.03632538631744091
# VETUSDT and BTCUSDT: p-value = 0.656311266636102
# VETUSDT and BTTUSDT: p-value = 0.0024365344935029926
# VETUSDT and DASHUSDT: p-value = 0.08700164788103615
# VETUSDT and EOSUSDT: p-value = 0.09287096638118114
# VETUSDT and ETCUSDT: p-value = 0.1569821018521914
# VETUSDT and ETHUSDT: p-value = 0.08687839733207503
# VETUSDT and HOTUSDT: p-value = 0.016112778593991565
# VETUSDT and IOTAUSDT: p-value = 0.23632942124268713
# VETUSDT and LINKUSDT: p-value = 0.3071940153436565
# VETUSDT and LTCUSDT: p-value = 0.260683267393226
# VETUSDT and NEOUSDT: p-value = 0.006866787109072155
# VETUSDT and OMGUSDT: p-value = 0.17932129162656307
# VETUSDT and QTUMUSDT: p-value = 0.0005311840961136502
# VETUSDT and THETAUSDT: p-value = 0.06868025572033577
# VETUSDT and TRXUSDT: p-value = 9.748104804135583e-05
# VETUSDT and TRXUSDT.1: p-value = 0.0
# VETUSDT and VETUSDT: p-value = 0.0
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py:1432: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   .. [1] https://en.wikipedia.org/wiki/Granger_causality
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py:1432: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   .. [1] https://en.wikipedia.org/wiki/Granger_causality
# VETUSDT and XLMUSDT: p-value = 0.19682325982510251
# VETUSDT and XMRUSDT: p-value = 0.031455465792729766
# VETUSDT and XRPUSDT: p-value = 4.383628968054698e-05
# XLMUSDT and ADAUSDT: p-value = 0.3939763906939569
# XLMUSDT and BATUSDT: p-value = 0.19312488337484168
# XLMUSDT and BTCUSDT: p-value = 0.004054791985463474
# XLMUSDT and BTTUSDT: p-value = 0.1507399316649502
# XLMUSDT and DASHUSDT: p-value = 0.02151727534994168
# XLMUSDT and EOSUSDT: p-value = 0.26497125265654053
# XLMUSDT and ETCUSDT: p-value = 0.3904944819617281
# XLMUSDT and ETHUSDT: p-value = 0.008282414199067193
# XLMUSDT and HOTUSDT: p-value = 0.1295730708904544
# XLMUSDT and IOTAUSDT: p-value = 0.09685276406200644
# XLMUSDT and LINKUSDT: p-value = 0.005043898805779577
# XLMUSDT and LTCUSDT: p-value = 0.008976865951497477
# XLMUSDT and NEOUSDT: p-value = 0.03384682666735403
# XLMUSDT and OMGUSDT: p-value = 0.08918462529201232
# XLMUSDT and QTUMUSDT: p-value = 0.06800715859504744
# XLMUSDT and THETAUSDT: p-value = 0.0622126668324501
# XLMUSDT and TRXUSDT: p-value = 0.11138577042363307
# XLMUSDT and TRXUSDT.1: p-value = 0.13660274949478768
# XLMUSDT and VETUSDT: p-value = 0.13660274949478768
# XLMUSDT and XLMUSDT: p-value = 0.0
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py:1432: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   .. [1] https://en.wikipedia.org/wiki/Granger_causality
# XLMUSDT and XMRUSDT: p-value = 0.026236473654038018
# XLMUSDT and XRPUSDT: p-value = 0.2823563666456856
# XMRUSDT and ADAUSDT: p-value = 0.25221880186390333
# XMRUSDT and BATUSDT: p-value = 0.12853051684790112
# XMRUSDT and BTCUSDT: p-value = 0.4120179392914972
# XMRUSDT and BTTUSDT: p-value = 0.07500955374398079
# XMRUSDT and DASHUSDT: p-value = 0.06652975426114412
# XMRUSDT and EOSUSDT: p-value = 0.14330963738733504
# XMRUSDT and ETCUSDT: p-value = 0.22518753674539166
# XMRUSDT and ETHUSDT: p-value = 0.023650163955702755
# XMRUSDT and HOTUSDT: p-value = 0.12041038307059632
# XMRUSDT and IOTAUSDT: p-value = 0.1521952909634287
# XMRUSDT and LINKUSDT: p-value = 0.007115105781378355
# XMRUSDT and LTCUSDT: p-value = 0.02891399674324246
# XMRUSDT and NEOUSDT: p-value = 0.0003488755542096436
# XMRUSDT and OMGUSDT: p-value = 0.0073215074511194566
# XMRUSDT and QTUMUSDT: p-value = 0.011716496422122835
# XMRUSDT and THETAUSDT: p-value = 0.08011276478408957
# XMRUSDT and TRXUSDT: p-value = 0.0027289412851499812
# XMRUSDT and TRXUSDT.1: p-value = 0.02890300093156758
# XMRUSDT and VETUSDT: p-value = 0.02890300093156758
# XMRUSDT and XLMUSDT: p-value = 0.03926092529270067
# XMRUSDT and XMRUSDT: p-value = 0.0
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py:1432: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   .. [1] https://en.wikipedia.org/wiki/Granger_causality
# XMRUSDT and XRPUSDT: p-value = 0.004162892949529718
# XRPUSDT and ADAUSDT: p-value = 0.047749607373154306
# XRPUSDT and BATUSDT: p-value = 0.04976569123494735
# XRPUSDT and BTCUSDT: p-value = 0.2482619067477383
# XRPUSDT and BTTUSDT: p-value = 0.00013727683061535572
# XRPUSDT and DASHUSDT: p-value = 0.017395209851242297
# XRPUSDT and EOSUSDT: p-value = 0.01813090475865949
# XRPUSDT and ETCUSDT: p-value = 0.0021547580075638203
# XRPUSDT and ETHUSDT: p-value = 0.008787432690656394
# XRPUSDT and HOTUSDT: p-value = 0.00385206715379733
# XRPUSDT and IOTAUSDT: p-value = 0.061312378324967894
# XRPUSDT and LINKUSDT: p-value = 0.10949008034043334
# XRPUSDT and LTCUSDT: p-value = 0.05236434481766909
# XRPUSDT and NEOUSDT: p-value = 1.4466017465833238e-05
# XRPUSDT and OMGUSDT: p-value = 0.06105748560915428
# XRPUSDT and QTUMUSDT: p-value = 1.9745812250657498e-06
# XRPUSDT and THETAUSDT: p-value = 0.03201188799927085
# XRPUSDT and TRXUSDT: p-value = 6.225576663503759e-05
# XRPUSDT and TRXUSDT.1: p-value = 1.5100897807255148e-05
# XRPUSDT and VETUSDT: p-value = 1.5100897807255148e-05
# XRPUSDT and XLMUSDT: p-value = 0.19843959278777729
# XRPUSDT and XMRUSDT: p-value = 0.0015769147974147172
# XRPUSDT and XRPUSDT: p-value = 0.0
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/stattools.py:1432: CollinearityWarning: y0 and y1 are (almost) perfectly colinear.Cointegration test is not reliable in this case.
#   .. [1] https://en.wikipedia.org/wiki/Granger_causality
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-9d85ae7e53ba> in <module>()
#       8     print(a1 + ' and ' + a2 + ': p-value = ' + str(test_result[1]))
#       9   coint_mat.append(coint_one)
# ---> 10 coint_mat = pd.DataFrame(coint_all, columns = assets, index=assets)
#      11
#      12 sn.heatmap(coint_mat, annot=True)
#
# NameError: name 'coint_all' is not defined

# %%
coint_mat = pd.DataFrame(coint_mat, columns = assets, index=assets)
sn.heatmap(coint_mat, annot=True)
# coint_mat.to_csv(r'/content/coint_mat_alltime.csv')

# %%
# # cointegration test P-value for every possible pair (separate test period - 2000h)
# period = 2000
# N = data.shape[0]//period
# coint_all = {}
# for n in range(N):
#   data_period = data.iloc[n*period:(n+1)*period]

#   coint_period = []
#   for a1 in assets:
#     coint_one = []
#     for a2 in assets:
#       test_result = ts.coint(data[a1], data[a2])
#       coint_one.append(test_result[1])
#       # print(a1 + ' and ' + a2 + ': p-value = ' + str(test_result[1]))
#     coint_period.append(coint_one)
#   coint_period = pd.DataFrame(coint_period, columns = assets, index=assets)
#   sn.heatmap(coint_period, annot=True)
#   coint_all[data.index[n*period]] = coint_period

# %%
coint_mat = pd.read_csv('/content/coint_mat_alltime.csv',index_col=0)
assets = coint_mat.columns
coint_mat
# Out:
#             ADAUSDT   BATUSDT   BTCUSDT  ...   XLMUSDT   XMRUSDT   XRPUSDT
# ADAUSDT    0.000000  0.813368  0.936441  ...  0.699669  0.516650  0.303212
# BATUSDT    0.431613  0.000000  0.206446  ...  0.152163  0.073757  0.054532
# BTCUSDT    0.826118  0.284860  0.000000  ...  0.005334  0.388713  0.430182
# BTTUSDT    0.067782  0.000026  0.180837  ...  0.086285  0.028395  0.000112
# DASHUSDT   0.054233  0.009066  0.031266  ...  0.008899  0.018167  0.010863
# EOSUSDT    0.004068  0.007853  0.025419  ...  0.014931  0.004600  0.000792
# ETCUSDT    0.014675  0.398277  0.434476  ...  0.319189  0.134450  0.003162
# ETHUSDT    0.007618  0.537617  0.949636  ...  0.022123  0.048149  0.043930
# HOTUSDT    0.090199  0.000010  0.175927  ...  0.077587  0.044527  0.003216
# IOTAUSDT   0.606790  0.000289  0.195346  ...  0.094572  0.111691  0.103065
# LINKUSDT   0.204182  0.287566  0.200685  ...  0.006363  0.005203  0.188019
# LTCUSDT    0.224349  0.187473  0.105420  ...  0.008491  0.016979  0.064294
# NEOUSDT    0.046796  0.007058  0.291074  ...  0.032771  0.000216  0.000019
# OMGUSDT    0.086621  0.191526  0.090132  ...  0.056088  0.002820  0.054448
# QTUMUSDT   0.005741  0.002010  0.162768  ...  0.036514  0.004482  0.000002
# THETAUSDT  0.117888  0.000001  0.332854  ...  0.076735  0.075937  0.076299
# TRXUSDT    0.117317  0.000491  0.183387  ...  0.084763  0.000979  0.000075
# TRXUSDT.1  0.100205  0.036325  0.656311  ...  0.196823  0.031455  0.000044
# VETUSDT    0.100205  0.036325  0.656311  ...  0.196823  0.031455  0.000044
# XLMUSDT    0.393976  0.193125  0.004055  ...  0.000000  0.026236  0.282356
# XMRUSDT    0.252219  0.128531  0.412018  ...  0.039261  0.000000  0.004163
# XRPUSDT    0.047750  0.049766  0.248262  ...  0.198440  0.001577  0.000000
#
# [22 rows x 22 columns]

# %%
tradepairs = []
for i in range(len(assets)):
  for j in range(i+1,len(assets)):
    if coint_mat.iloc[i,j] < 0.05: #significant cointegration effects
      tradepairs.append((assets[i],assets[j]))
print(len(tradepairs))
# Out:
# 109

# %%
n = len(tradepairs)
fig = plt.figure(figsize=(30,15))
ax = plt.axes()
ax.xaxis.set_major_locator(plt.MaxNLocator(20))
plt.rcParams.update({'font.size':10})
plt.xticks(rotation=45)
  
for ix, pair in enumerate(tradepairs):
  plt.subplot(n//4+1,4,ix+1)  
  plt.plot(norm_prices[pair[0]])
  plt.plot(norm_prices[pair[1]])
  plt.xlabel("Date")
  plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
  ax.grid(True)
  plt.legend(pair, loc='best')
plt.show()

# %% [markdown]
# **2. FORECAST ADJUSTED PRICE FOR SELECTED PAIR**

# %%
#2.2.1, indexing  Concatenated data

BTC_AdjClosing=btc['Adj Close']
BTC_AdjClosing = pd.DataFrame(btc['Adj Close']) 
BTC_AdjClosing.rename(columns = {'Adj Close':'BTC_AdjClosing'}, inplace = True) 

ETH_AdjClosing=eth['Adj Close']
ETH_AdjClosing = pd.DataFrame(eth['Adj Close']) 
ETH_AdjClosing.rename(columns = {'Adj Close':'ETH_AdjClosing'}, inplace = True) 
ETH_AdjClosing.head()


Crypto_pair= pd.concat([BTC_AdjClosing,ETH_AdjClosing], ignore_index=False,axis=1)

Crypto_pair['Date'] = pd.to_datetime(btc['Date'],format='%Y-%m-%d')
Crypto_pair.index = btc['Date']

Crypto_pair.head()
# Out:
#             BTC_AdjClosing  ETH_AdjClosing       Date
# Date
# 2018-01-01    13657.200195      772.640991 2018-01-01
# 2018-01-02    14982.099609      884.443970 2018-01-02
# 2018-01-03    15201.000000      962.719971 2018-01-03
# 2018-01-04    15599.200195      980.921997 2018-01-04
# 2018-01-05    17429.500000      997.719971 2018-01-05

# %%
Crypto_pair.shape
# Out:
# (610, 3)

# %%
# #2.2.3 The Adjusted Closing plot for Bitcoin and Ethereum

# plt.figure(figsize=(16,8))
# plt.rcParams.update({'font.size':10})
# plt.xticks(rotation=45)
# ax = plt.axes()
# ax.xaxis.set_major_locator(plt.MaxNLocator(20))
# plt.plot(Crypto_pair['BTC_AdjClosing'],color='blue',  label='Bitcoin Adjusted Closing price')
# plt.plot(Crypto_pair['ETH_AdjClosing'],color='red',  label='ETH Adjusted Closing price')
# plt.xlabel("Date")

# ax.grid(True)
# plt.legend(loc='best')
# plt.show()

# %% [markdown]
# Now lets consider the graphical representation for the returns for both BTC and ETH

# %%
# ##2.2.4 graphical representation for the returns for both BTC and ETH

# plt.figure(figsize=(16,8))
# plt.rcParams.update({'font.size':10})
# plt.xticks(rotation=45)
# ax = plt.axes()
# ax.xaxis.set_major_locator(plt.MaxNLocator(20))
# plt.plot(dt['BTC_RET'],color='red',label='BTC PERCENTAGE CHANGE')
# plt.plot(dt['ETH_RET'],color='blue',label='ETH PERCENTAGE CHANGE')
# plt.xlabel("Date")
# plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
# ax.grid(True)
# plt.legend(loc='best')
# plt.show()

# %%
# #2.2.5 THE CUMMULATIVE RETURNS PLOT  FOR BTC AND ETH

# plt.figure(figsize=(16,8))
# plt.rcParams.update({'font.size':10})
# plt.xticks(rotation=45)
# ax = plt.axes()
# ax.xaxis.set_major_locator(plt.MaxNLocator(20))
# plt.plot(dtc['BTC_C.RET'],label='BTC CUMMULATIVE RETURNS')
# plt.plot(dtc['ETH_C.RET'],label='ETH CUMMULATIVE RETURNS')
# plt.xlabel("Date")
# plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
# ax.grid(True)
# plt.legend(loc='best')
# plt.show()

# %%
# #2.3.0 Pairs Spread 
# # 2.3.1. BTC-ETH Spread Calculation
# BTC_ETH = dt['BTC_RET'] - dt['ETH_RET']

# plt.figure(figsize=(16,8))
# plt.rcParams.update({'font.size':10})
# plt.xticks(rotation=45)
# ax = plt.axes()
# ax.xaxis.set_major_locator(plt.MaxNLocator(20))
# plt.plot(BTC_ETH,color='green',label='BTC_ETH SPREAD')
# plt.suptitle('BTC-ETH SPREAD')
# ax.axhline(BTC_ETH.mean(), color='orange')
# ax.grid(True)
# plt.xlabel("Date")
# plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
# plt.legend(loc='best')
# plt.show()

# %% [markdown]
# *LET'S ATTEMPT TO PREDICT THE ADJUSTED PRICE FOR THE BASE CURRENCY - BITCOIN*
# *we will get the best best forecast model for the currency and then procceed to the spread*

# %% [markdown]
# Commonly, an analyst may use various predictive tools in other to predict or forecast the trend of price movement. For this assignment we will be using the Long Short-Term Memory model (LSTM), the Moving Average as well as the ARIMA (Auto Regressive Integrated Moving Average).

# %% [markdown]
# ### Long Short Term Memory (LSTM) ###
# LSTMs (“long short-term memory” units) is one of the most remarkable Recurrent neural networks. The LSTM is designed to identify data sequence patterns. Long Short-Term Memory networks are the best quality level to building RNN.  and they have demonstrated to be exceptionally powerful for succession forecast problems. By training the models via back-propagation, the LSTM stores useful data while forgetting any that is deemed otherwise.  Examples of such data that can be forecasted via LSTM are stock markets, sensors, genomes, words and handwriting.

# %%
np.random.seed(0)
# 2.4.0 converting dataset into x_train and y_train
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(BTC_AdjClosing)

# %%
# 2.4.1 setting training and testing range

x_train, y_train = [], []
for i in range(80,len(BTC_train)):
    x_train.append(scaled_data[i-80:i,0])
    y_train.append(scaled_data[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1))

x_train.shape
# Out:
# (408, 80, 1)

# %%
# 2.4.2 create and fit the LSTM network

model = Sequential()
model.add(LSTM(units=13, return_sequences=True, input_shape=(x_train.shape[1],1)))
model.add(LSTM(units=3))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam',metrics=['accuracy'])
model.fit(x_train, y_train, epochs=13, batch_size=1, verbose=2)
# Out:
# Epoch 1/13
# 408/408 - 7s - loss: 0.0036 - accuracy: 0.0025 - 7s/epoch - 17ms/step
# Epoch 2/13
# 408/408 - 5s - loss: 0.0019 - accuracy: 0.0025 - 5s/epoch - 13ms/step
# Epoch 3/13
# 408/408 - 5s - loss: 0.0015 - accuracy: 0.0025 - 5s/epoch - 13ms/step
# Epoch 4/13
# 408/408 - 5s - loss: 0.0014 - accuracy: 0.0025 - 5s/epoch - 13ms/step
# Epoch 5/13
# 408/408 - 5s - loss: 0.0011 - accuracy: 0.0025 - 5s/epoch - 13ms/step
# Epoch 6/13
# 408/408 - 5s - loss: 8.9761e-04 - accuracy: 0.0025 - 5s/epoch - 13ms/step
# Epoch 7/13
# 408/408 - 5s - loss: 7.0998e-04 - accuracy: 0.0025 - 5s/epoch - 13ms/step
# Epoch 8/13
# 408/408 - 5s - loss: 6.6571e-04 - accuracy: 0.0025 - 5s/epoch - 13ms/step
# Epoch 9/13
# 408/408 - 5s - loss: 6.1548e-04 - accuracy: 0.0025 - 5s/epoch - 13ms/step
# Epoch 10/13
# 408/408 - 5s - loss: 5.4315e-04 - accuracy: 0.0025 - 5s/epoch - 13ms/step
# Epoch 11/13
# 408/408 - 5s - loss: 5.0524e-04 - accuracy: 0.0025 - 5s/epoch - 13ms/step
# Epoch 12/13
# 408/408 - 5s - loss: 4.7004e-04 - accuracy: 0.0025 - 5s/epoch - 13ms/step
# Epoch 13/13
# 408/408 - 5s - loss: 4.4195e-04 - accuracy: 0.0025 - 5s/epoch - 13ms/step

# %%
# 2.4.3  predicting 122 values, using past 80 from the train data
inputs = BTC_AdjClosing[len(BTC_AdjClosing) - len(BTC_test) - 80:].values
inputs = inputs.reshape(-1,1)
inputs  = scaler.transform(inputs)
# Out:
# C:\Users\xinye\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:445: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 80, 13)            780
#
#  lstm_1 (LSTM)               (None, 3)                 204
#
#  dense (Dense)               (None, 1)                 4
#
# =================================================================
# Total params: 988
# Trainable params: 988
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# 2.4.4 setting the traning and testing range for the LSTM 
X_test = []
for i in range(80,inputs.shape[0]):
    X_test.append(inputs[i-80:i,0])
X_test = np.array(X_test)
print(X_test.shape)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
closing_priceL = model.predict(X_test)
closing_priceL = scaler.inverse_transform(closing_priceL)
# Out:
# (122, 80)

# %%
# 2.4.5 RMSE for the LSTM 
rms=np.sqrt(np.mean(np.power((BTC_test['BTC_AdjClosing'].values-closing_priceL),2)))
rms
# Out:
# 2287.5078853214072

# %%
# 2.4.6 MAPE for the LSTM 
mape = np.mean(np.abs(closing_priceL - BTC_test['BTC_AdjClosing'].values)/np.abs(BTC_test['BTC_AdjClosing'].values))
mape
# Out:
# 0.19817923731908849

# %%
# 2.4.7 MPE for the LSTM 
mpe = np.mean((closing_priceL - BTC_test['BTC_AdjClosing'].values)/BTC_test['BTC_AdjClosing'].values)
mpe
# Out:
# -0.02117480116769137

# %%
# 2.4.8 LSTM Forecast Plot

plt.figure(figsize=(16,8))
plt.rcParams.update({'font.size':10})
plt.xticks(rotation=45)
ax = plt.axes()
ax.xaxis.set_major_locator(plt.MaxNLocator(20))
BTC_test['LSTM_Predictions'] = closing_priceL
plt.plot(BTC_train['BTC_AdjClosing'],label='train close')
plt.plot(BTC_test['BTC_AdjClosing'],label='BTC_test Close')
plt.plot(BTC_test['LSTM_Predictions'],label='LSTM_predictions')
plt.xlabel("Date")

plt.ylabel("Price") 
ax.grid(True)
plt.legend(loc='best')
plt.show()
# Out:
# C:\Users\xinye\AppData\Local\Temp/ipykernel_17100/1142793045.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BTC_test['LSTM_Predictions'] = closing_priceL

# %%
# 2.4.9 Correlation between the predicted via LSTM and the actual 
corr_LSTM = np.corrcoef(BTC_test['LSTM_Predictions'].dropna().values, BTC_test['BTC_AdjClosing'].dropna().values)[0,1] 

print('correlation between %s and %s is %f'%('test_BTC_AdjClosing', 'LSTM_Predictions',corr_LSTM))
# Out:
# correlation between test_BTC_AdjClosing and LSTM_Predictions is 0.947002

# %% [markdown]
# ### IMPLICATION ###
# *The LSTM model has the following results:*
#
# RMS = 2323.0302070760094
# MAPE = 0.2045987551428502
# MPE = 0.011401705487805586
# Correlation = 94.8%
# We will investigate the other models to see if we can get a better result

# %% [markdown]
# For the next two models we have to investigate the ACF and the PACF of the returns and the square of the returns of our time series data. ACF stands for Auto Correlation function and PACF stands for Partial Auto correlation function.  both are meant to measure the level of correlation or similarity of a particular time series with a previous time. This often helps us determine the most relevant part of the Moving-Average and ARIMA model

# %%
# 2.5.0.1 ACF for Bitcoin returns 

plot_acf(dt['BTC_RET'], lags=50)
pyplot.show()

# %%
# 2.5.0.2 PACF for Bitcoin returns 

plot_pacf(dt['BTC_RET'], lags=50)
pyplot.show()
# Out:
# C:\Users\xinye\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
# 2.5.0.3 lets square the returns and try the ACF and PACF plots again 
BTC_RET_SQ=(dt['BTC_RET'])**2
BTC_RET_SQ.head()
# Out:
# Date
# 2018-01-03    0.000213
# 2018-01-04    0.000686
# 2018-01-05    0.013767
# 2018-01-06    0.000031
# 2018-01-07    0.003585
# Name: BTC_RET, dtype: float64

# %%
# 2.5.0.4  ACF for Bitcoin returns squared 
plot_acf(BTC_RET_SQ, lags=50)
pyplot.show()

# %%
# 2.5.0.5  PACF for Bitcoin returns squared 
plot_pacf(BTC_RET_SQ, lags=50)
pyplot.show()
# Out:
# C:\Users\xinye\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# However, ACF and the PACF suggests an AR model.

# %% [markdown]
# ### MOVING AVERAGE ###
# **In budgetary applications, a Moving Average is the unweighted mean of the past n data. In any case, in other applications, the mean is typically taken from an equivalent number of information on either side of a focal worth. This guarantees variations in the mean are lined up with the variations in the information as opposed to being moved in time.**

# %%
# 2.6.0 moving average model 

preds = []
for i in range(0,BTC_test.shape[0]):
    a = BTC_train['BTC_AdjClosing'][len(BTC_train)-122+i:].sum() + sum(preds)
    b = a/122
    preds.append(b)

# %%
# 2.6.1 RMSE for moving average model

rms=np.sqrt(np.mean(np.power((np.array(BTC_test['BTC_AdjClosing'])-preds),2)))
print('\n RMSE value on validation set:')
print(rms)
# Out:
#  RMSE value on validation set:
# 5408.400898834493

# %%
# 2.6.2 MAPE for moving average model

mape=np.mean(np.abs(preds - BTC_test['BTC_AdjClosing'].values)/np.abs(BTC_test['BTC_AdjClosing'].values))
mape
# Out:
# 0.5255070605539833

# %%
# 2.6.3 MPE for moving average model

mpe = np.mean((preds - BTC_test['BTC_AdjClosing'].values)/BTC_test['BTC_AdjClosing'].values)
mpe
# Out:
# -0.5255070605539833

# %%
#2.6.4   moving average model Forecast plot

plt.figure(figsize=(16,8))
plt.rcParams.update({'font.size':10})
plt.xticks(rotation=45)
ax = plt.axes()
ax.xaxis.set_major_locator(plt.MaxNLocator(20))
BTC_test['MA_Predictions'] = 0
BTC_test['MA_Predictions'] = preds
plt.plot(BTC_train['BTC_AdjClosing'],label='BTC_train Close')
plt.plot(BTC_test['BTC_AdjClosing'],label='BTC_test Close')
plt.plot(BTC_test['MA_Predictions'],label='MA_Predictions')
plt.xlabel("Date")

ax.grid(True)
plt.legend(loc='best')
plt.show()
# Out:
# C:\Users\xinye\AppData\Local\Temp/ipykernel_17100/3711880504.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BTC_test['MA_Predictions'] = 0
# C:\Users\xinye\AppData\Local\Temp/ipykernel_17100/3711880504.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BTC_test['MA_Predictions'] = preds

# %%
#2.6.4  Correlation between the predicted via Moving Average and the actual  

corr_MA = np.corrcoef(BTC_test['MA_Predictions'].dropna().values, BTC_test['BTC_AdjClosing'].dropna().values)[0,1] 

print('correlation between %s and %s is %f'%('test_BTC_AdjClosing', 'Moving_Average',corr_MA))
# Out:
# correlation between test_BTC_AdjClosing and Moving_Average is 0.816826

# %% [markdown]
# ### IMPLICATION ###
# The Moving Average model has the following results:
#
#
# RMS = 5408.400905373845
#
# MAPE = 0.525507061227389
#
# MPE = -0.525507061227389
#
# Correlation = 81.7%
#
# Evidently the LSTM has a better result than that of the Moving Average   We will investigate the other models to see if we can get a better result

# %% [markdown]
# ### ARIMA###
#
# *"ARIMA: AutoRegressive Integrated Moving Average. It is a class of model that gets a collection of different standard progressive structures in data (within a particular time series)."*
# **Source:https://machinelearningmastery.com/arima-for-time-series-forecasting-with-python/ How to Create an ARIMA Model for Time Series Forecasting in Python
# by Jason Brownlee**
#
# *ARIMA is an incredibly common genuine methodology for time series analysis. ARIMA models studies the past characteristics to envision the future characteristics. There are three critical parameters in ARIMA:*
#
# *p (past qualities utilized for forecasting the following worth)*
#
# *q (past gauge mistakes used to anticipate the future qualities)*
#
# *d (differencing order)*
#
# Parameter tuning for ARIMA consumes a huge amount of time. So we will use auto ARIMA which thus picks the best mix of (p,q,d) that gives the least error*

# %%
#2.7.0 ARIMA Model set up 
B_model = auto_arima(BTC_train, start_p=0, start_q=0,max_p=3, max_q=3, m=12,start_P=0, seasonal=True,d=1, D=1, trace=True,error_action='ignore',suppress_warnings=True)
B_model.fit(BTC_train)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,1,1)[12]             : AIC=inf, Time=0.38 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=7207.853, Time=0.02 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=7079.038, Time=0.17 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=inf, Time=0.41 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=7206.650, Time=0.03 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=7003.993, Time=0.45 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=inf, Time=1.76 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=inf, Time=0.55 sec
#  ARIMA(0,1,0)(2,1,0)[12]             : AIC=7003.840, Time=0.39 sec
#  ARIMA(0,1,0)(1,1,0)[12]             : AIC=7079.368, Time=0.12 sec
#  ARIMA(0,1,0)(2,1,1)[12]             : AIC=inf, Time=1.38 sec
#  ARIMA(0,1,0)(1,1,1)[12]             : AIC=inf, Time=0.34 sec
#  ARIMA(0,1,1)(2,1,0)[12]             : AIC=7004.126, Time=0.45 sec
#  ARIMA(1,1,1)(2,1,0)[12]             : AIC=inf, Time=3.38 sec
#  ARIMA(0,1,0)(2,1,0)[12] intercept   : AIC=7005.772, Time=1.22 sec
#
# Best model:  ARIMA(0,1,0)(2,1,0)[12]
# Total fit time: 11.066 seconds
# ARIMA(order=(0, 1, 0), scoring_args={}, seasonal_order=(2, 1, 0, 12),
#       suppress_warnings=True, with_intercept=False)

# %%
print(B_model.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                  488
# Model:             SARIMAX(0, 1, 0)x(2, 1, 0, 12)   Log Likelihood               -3498.920
# Date:                            Thu, 09 Dec 2021   AIC                           7003.840
# Time:                                    16:04:20   BIC                           7016.330
# Sample:                                         0   HQIC                          7008.751
#                                             - 488
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.S.L12      -0.7239      0.024    -30.537      0.000      -0.770      -0.677
# ar.S.L24      -0.4546      0.025    -18.494      0.000      -0.503      -0.406
# sigma2      1.416e+05   5029.648     28.145      0.000    1.32e+05    1.51e+05
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.34   Jarque-Bera (JB):               807.41
# Prob(Q):                              0.25   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.07   Skew:                            -0.38
# Prob(H) (two-sided):                  0.00   Kurtosis:                         9.34
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
#2.7.1 getting the ARIMA Model forecast prediction

forecast = B_model.predict(n_periods=122)
forecast = pd.DataFrame(forecast,index = BTC_test.index,columns=['Prediction'])

# %%
#2.7.2 MAPE for the  ARIMA Model forecast 
mape = np.mean(np.abs(forecast['Prediction'] - BTC_test['BTC_AdjClosing'])/np.abs(BTC_test['BTC_AdjClosing']))
mape
# Out:
# 0.14401306379353615

# %%
#2.7.3 RMSE for the  ARIMA Model forecast 

rms=np.sqrt(np.mean(np.power((np.array(BTC_test['BTC_AdjClosing'])-np.array(forecast['Prediction'])),2)))
rms
# Out:
# 1821.570318261048

# %%
#2.7.4 MPE for the  ARIMA Model forecast 

mpe = np.mean((forecast['Prediction'].dropna().values  - BTC_test['BTC_AdjClosing'].dropna().values)/BTC_test['BTC_AdjClosing'].dropna().values)
mpe
# Out:
# -0.13337853383967058

# %%
#2.7.5   ARIMA Model Forecast plot
plt.figure(figsize=(16,8))
plt.rcParams.update({'font.size':10})
plt.xticks(rotation=45)
ax = plt.axes()
ax.xaxis.set_major_locator(plt.MaxNLocator(20))
plt.plot(BTC_train['BTC_AdjClosing'],label='BTC_TRAINING')
plt.plot(BTC_test['BTC_AdjClosing'],label='BTC_TEST')
plt.plot(forecast['Prediction'])
plt.xlabel("Date")
 
plt.ylabel("Price") 
ax.grid(True)
plt.legend(loc='best')
plt.show()

# %%
#2.7.6  Correlation between the predicted via ARIMA and the actual 

corr_ARIMA = np.corrcoef(forecast['Prediction'].dropna().values, BTC_test['BTC_AdjClosing'].dropna().values)[0,1] 

print('correlation between %s and %s is %f'%('test_BTC_AdjClosing', 'ARIMA_Predictions',corr_ARIMA))
# Out:
# correlation between test_BTC_AdjClosing and ARIMA_Predictions is 0.696205

# %% [markdown]
# ### IMPLICATION ###
# *The ARIMA model has the following results:*
#
# *RMS = 2914.339206649189*
#
# *MAPE = 0.25884675669532237*
#
# *MPE = -0.2587916064701649*
#
# *Correlation = 65.8%
#
#
# *Considering the previous results, we need to still investigate more as none has given a result better than the LSTM yet.
# Evidently the LSTM has a better result than that of the ARIMA, We will investigate the other model to see if we can get a better result*

# %% [markdown]
# ### The Artificial Neural Network ###
#
# *Artificial Neural Network is a data handling model which is utilized to contemplate the conduct of an intricate framework by computer replication. It is incited by the organic method which the human mind processes its data. The key component of the model is the novel structure of the data preparing framework. The objective of artificial neural network is to analyze information in a similarly manner a human mind would*
#
# **Artificial Neural Networks (ANN's) utilize three neuron layers these are:**
#
# *1.	input layer,*
#
# *2.	hidden or concealed layer, and*
#
# *3.	the Output or yield layers.*
#
#
# *These help to get the anticipated forecasts. The artificial nodes are the fundamentally prepared components of artificial neural network*

# %%
#2.8.0 setting the training and testing range for the ANN model

np.random.seed(0)
x_trainB, y_trainB = [], []
for i in range(80,len(BTC_train)):
    x_trainB.append(scaled_data[i-80:i,0])
    y_trainB.append(scaled_data[i,0])
x_trainB, y_trainB = np.array(x_trainB), np.array(y_trainB)

x_trainB = np.reshape(x_trainB, (x_trainB.shape[0],x_trainB.shape[1]))

# %%
x_trainB.shape
# Out:
# (408, 80)

# %%
#2.8.1 setting the ANN model

modelB = Sequential()
modelB.add(Dense(units = 13, kernel_initializer = 'uniform', activation = 'relu', input_dim = 80))
np.random.seed(0)
modelB.add(Dense(units =13, kernel_initializer = 'uniform', activation      = 'relu'))
modelB.add(Dense(units = 1, kernel_initializer = 'uniform', activation        = 'sigmoid'))
modelB.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics 
         = ['accuracy'])
modelB.fit(x_trainB, y_trainB, batch_size = 1, epochs = 13,verbose=2)
# Out:
# Epoch 1/13
# 408/408 - 0s - loss: 0.0546 - accuracy: 0.0025 - 318ms/epoch - 779us/step
# Epoch 2/13
# 408/408 - 0s - loss: 0.0288 - accuracy: 0.0025 - 153ms/epoch - 375us/step
# Epoch 3/13
# 408/408 - 0s - loss: 0.0128 - accuracy: 0.0025 - 156ms/epoch - 383us/step
# Epoch 4/13
# 408/408 - 0s - loss: 0.0057 - accuracy: 0.0025 - 147ms/epoch - 360us/step
# Epoch 5/13
# 408/408 - 0s - loss: 0.0034 - accuracy: 0.0025 - 147ms/epoch - 360us/step
# Epoch 6/13
# 408/408 - 0s - loss: 0.0024 - accuracy: 0.0025 - 149ms/epoch - 365us/step
# Epoch 7/13
# 408/408 - 0s - loss: 0.0018 - accuracy: 0.0025 - 150ms/epoch - 367us/step
# Epoch 8/13
# 408/408 - 0s - loss: 0.0013 - accuracy: 0.0025 - 157ms/epoch - 384us/step
# Epoch 9/13
# 408/408 - 0s - loss: 0.0010 - accuracy: 0.0025 - 152ms/epoch - 372us/step
# Epoch 10/13
# 408/408 - 0s - loss: 9.3637e-04 - accuracy: 0.0025 - 154ms/epoch - 377us/step
# Epoch 11/13
# 408/408 - 0s - loss: 7.3878e-04 - accuracy: 0.0025 - 148ms/epoch - 362us/step
# Epoch 12/13
# 408/408 - 0s - loss: 6.9369e-04 - accuracy: 0.0025 - 146ms/epoch - 357us/step
# Epoch 13/13
# 408/408 - 0s - loss: 6.5461e-04 - accuracy: 0.0025 - 147ms/epoch - 360us/step

# %%
print(modelB.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_1 (Dense)             (None, 13)                1053
#
#  dense_2 (Dense)             (None, 13)                182
#
#  dense_3 (Dense)             (None, 1)                 14
#
# =================================================================
# Total params: 1,249
# Trainable params: 1,249
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#2.8.2 predicting 122 values, using past 80 from the train data
inputsB = BTC_AdjClosing[len(BTC_AdjClosing) - len(BTC_test) - 80:].values
inputsB = inputsB.reshape(-1,1)
inputsB  = scaler.transform(inputsB)
# Out:
# C:\Users\xinye\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:445: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
#2.8.3 setting the ANN outcome range and size

X_testB = []
for i in range(80,inputsB.shape[0]):
    X_testB.append(inputsB[i-80:i,0])
X_testB = np.array(X_testB)
print(X_testB.shape)
X_testB = np.reshape(X_testB, (X_testB.shape[0],X_testB.shape[1]))
X_testB.shape
closing_priceB = modelB.predict(X_testB)
closing_priceB = scaler.inverse_transform(closing_priceB)
# Out:
# (122, 80)

# %%
#2.8.4 the RMSE for the ANN model

RMS=np.sqrt(np.mean(np.power((BTC_test['BTC_AdjClosing'].values-closing_priceB),2)))
RMS
# Out:
# 2338.50173489058

# %%
#2.8.5 the MAPE for the ANN model

MAPE = np.mean(np.abs(closing_priceB - BTC_test['BTC_AdjClosing'].values)/np.abs(BTC_test['BTC_AdjClosing'].values))
MAPE
# Out:
# 0.1960892214586186

# %%
#2.8.6 the MPE for the ANN model

MPE = np.mean((closing_priceB - BTC_test['BTC_AdjClosing'].values)/BTC_test['BTC_AdjClosing'].values)
MPE
# Out:
# -0.10318045846167237

# %%
#2.8.7   ANN Model Forecast plot

plt.figure(figsize=(16,8))
plt.rcParams.update({'font.size':10})
plt.xticks(rotation=45)
ax = plt.axes()
ax.xaxis.set_major_locator(plt.MaxNLocator(20))
BTC_test['ANN_Predictions'] = closing_priceB
plt.plot(BTC_train['BTC_AdjClosing'],label='BTC_TRAINING_close')
plt.plot(BTC_test['BTC_AdjClosing'],label='BTC_TEST_close')
plt.plot(BTC_test['ANN_Predictions'],label='ANN_predictions')
plt.xlabel("Date")
 
plt.ylabel("Price") 
ax.grid(True)
plt.legend(loc='best')
plt.show()
# Out:
# C:\Users\xinye\AppData\Local\Temp/ipykernel_17100/4014253728.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BTC_test['ANN_Predictions'] = closing_priceB

# %%
#2.8.8   Correlation between the predicted via ANN and the actual 

corr_ANN = np.corrcoef(BTC_test['ANN_Predictions'].dropna().values, BTC_test['BTC_AdjClosing'].dropna().values)[0,1] 

print('correlation between %s and %s is %f'%('test_BTC_AdjClosing', 'ANN_Predictions',corr_ANN))
# Out:
# correlation between test_BTC_AdjClosing and ANN_Predictions is 0.893722

# %%
#2.9  Correlation between the predicted BTC prices and the actual


#Correlation between the predicted via LSTM and the actual 
corr_LSTM = np.corrcoef(BTC_test['LSTM_Predictions'].dropna().values, BTC_test['BTC_AdjClosing'].dropna().values)[0,1] 

print('correlation between %s and %s is %f'%('test_BTC_AdjClosing', 'LSTM_Predictions',corr_LSTM))

#Correlation between the predicted via MA and the actual 
corr_MA = np.corrcoef(BTC_test['MA_Predictions'].dropna().values, BTC_test['BTC_AdjClosing'].dropna().values)[0,1] 

print('correlation between %s and %s is %f'%('test_BTC_AdjClosing', 'Moving_Average',corr_MA))

#Correlation between the predicted via ARIMA and the actual 

corr_ARIMA = np.corrcoef(forecast['Prediction'].dropna().values, BTC_test['BTC_AdjClosing'].dropna().values)[0,1] 

print('correlation between %s and %s is %f'%('test_BTC_AdjClosing', 'ARIMA_Predictions',corr_ARIMA))


#Correlation between the predicted via ANN and the actual 
corr_ANN = np.corrcoef(BTC_test['ANN_Predictions'].dropna().values, BTC_test['BTC_AdjClosing'].dropna().values)[0,1] 

print('correlation between %s and %s is %f'%('test_BTC_AdjClosing', 'ANN_Predictions',corr_ANN))
# Out:
# correlation between test_BTC_AdjClosing and LSTM_Predictions is 0.947002
# correlation between test_BTC_AdjClosing and Moving_Average is 0.816826
# correlation between test_BTC_AdjClosing and ARIMA_Predictions is 0.696205
# correlation between test_BTC_AdjClosing and ANN_Predictions is 0.893722

# %% [markdown]
# ***we consider the LSTM for the Second Crypto Currency in our Pair (Euthereum, ETH)***

# %%
ETH_AdjClosing.index = eth['Date']

# %%
#2.9a. split into train and validation/testing
ETH_train =ETH_AdjClosing[:488]
ETH_test = ETH_AdjClosing[488:]

# %%
print('\n Shape of training set:')
print(ETH_train.shape)
print('\n Shape of test set:')
print(ETH_test.shape)
# Out:
#  Shape of training set:
# (488, 1)
#
#  Shape of test set:
# (122, 1)

# %%
np.random.seed(0)
##2.9b converting dataset into x_train and y_train
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(ETH_AdjClosing)

# %%
##2.9c setting training and testing range
x_traine, y_traine = [], []
for i in range(80,len(ETH_train)):
    x_traine.append(scaled_data[i-80:i,0])
    y_traine.append(scaled_data[i,0])
x_traine, y_traine = np.array(x_traine), np.array(y_traine)

x_traine = np.reshape(x_traine, (x_traine.shape[0],x_traine.shape[1],1))

x_traine.shape
# Out:
# (408, 80, 1)

# %%
#2.9d create and fit the LSTM network
modele = Sequential()
modele.add(LSTM(units=13, return_sequences=True, input_shape=(x_traine.shape[1],1)))
modele.add(LSTM(units=3))
modele.add(Dense(1))

modele.compile(loss='mean_squared_error', optimizer='adam',metrics=['accuracy'])
modele.fit(x_traine, y_traine, epochs=13, batch_size=1, verbose=2)
# Out:
# Epoch 1/13
# 408/408 - 6s - loss: 0.0065 - accuracy: 0.0025 - 6s/epoch - 16ms/step
# Epoch 2/13
# 408/408 - 5s - loss: 0.0016 - accuracy: 0.0025 - 5s/epoch - 12ms/step
# Epoch 3/13
# 408/408 - 5s - loss: 0.0013 - accuracy: 0.0025 - 5s/epoch - 12ms/step
# Epoch 4/13
# 408/408 - 5s - loss: 0.0010 - accuracy: 0.0025 - 5s/epoch - 13ms/step
# Epoch 5/13
# 408/408 - 5s - loss: 8.5280e-04 - accuracy: 0.0025 - 5s/epoch - 13ms/step
# Epoch 6/13
# 408/408 - 5s - loss: 8.0727e-04 - accuracy: 0.0025 - 5s/epoch - 13ms/step
# Epoch 7/13
# 408/408 - 5s - loss: 6.3046e-04 - accuracy: 0.0025 - 5s/epoch - 13ms/step
# Epoch 8/13
# 408/408 - 5s - loss: 6.9343e-04 - accuracy: 0.0025 - 5s/epoch - 13ms/step
# Epoch 9/13
# 408/408 - 5s - loss: 6.1777e-04 - accuracy: 0.0025 - 5s/epoch - 13ms/step
# Epoch 10/13
# 408/408 - 5s - loss: 6.1715e-04 - accuracy: 0.0025 - 5s/epoch - 13ms/step
# Epoch 11/13
# 408/408 - 5s - loss: 6.0754e-04 - accuracy: 0.0025 - 5s/epoch - 13ms/step
# Epoch 12/13
# 408/408 - 5s - loss: 6.3342e-04 - accuracy: 0.0025 - 5s/epoch - 13ms/step
# Epoch 13/13
# 408/408 - 5s - loss: 6.2056e-04 - accuracy: 0.0025 - 5s/epoch - 13ms/step

# %%
#2.9e  predicting 122 values, using past 80 from the train data
inputse = ETH_AdjClosing[len(ETH_AdjClosing) - len(ETH_test) - 80:].values
inputse = inputse.reshape(-1,1)
inputse  = scaler.transform(inputse)
# Out:
# C:\Users\xinye\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\base.py:445: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
print(modele.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 80, 13)            780
#
#  lstm_3 (LSTM)               (None, 3)                 204
#
#  dense_4 (Dense)             (None, 1)                 4
#
# =================================================================
# Total params: 988
# Trainable params: 988
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
#2.9f setting testing range for ETH

X_teste = []
for i in range(80,inputse.shape[0]):
    X_teste.append(inputse[i-80:i,0])
X_teste = np.array(X_teste)
print(X_teste.shape)
X_teste = np.reshape(X_teste, (X_teste.shape[0],X_teste.shape[1],1))
closing_pricee = model.predict(X_teste)
closing_pricee = scaler.inverse_transform(closing_pricee)
# Out:
# (122, 80)

# %%
#2.9g  RMSE for ETH

rms=np.sqrt(np.mean(np.power((ETH_test['ETH_AdjClosing'].values-closing_pricee),2)))
rms
# Out:
# 59.55209914778031

# %%
#2.9h  MAPE for ETH

mape = np.mean(np.abs(closing_pricee - ETH_test['ETH_AdjClosing'].values)/np.abs(ETH_test['ETH_AdjClosing'].values))
mape
# Out:
# 0.21258635695880043

# %%
#2.9i   MPE for ETH
mpe = np.mean((closing_pricee - ETH_test['ETH_AdjClosing'].values)/ETH_test['ETH_AdjClosing'].values)
mpe
# Out:
# 0.04048213782572362

# %%
#2.9j   LST  Model Forecast plot for ETH

plt.figure(figsize=(16,8))
plt.rcParams.update({'font.size':10})
plt.xticks(rotation=45)
ax = plt.axes()
ax.xaxis.set_major_locator(plt.MaxNLocator(20))
ETH_test['Predictions'] = closing_pricee
plt.plot(ETH_train['ETH_AdjClosing'],label='train close')
plt.plot(ETH_test['ETH_AdjClosing'],label='ETH_test Close')
plt.plot(ETH_test['Predictions'],label='prediction')
plt.xlabel("Date")

plt.ylabel("Price") 

ax.grid(True)
plt.legend(loc='best')
plt.show()
# Out:
# C:\Users\xinye\AppData\Local\Temp/ipykernel_17100/326169077.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ETH_test['Predictions'] = closing_pricee

# %%
#2.9k  Correlation between the predicted ETH prices via LSTM and the actual 
corr_ETH_LSTM = np.corrcoef(ETH_test['Predictions'].dropna().values,ETH_test['ETH_AdjClosing'].dropna().values)[0,1] 

print('correlation between %s and %s is %f'%('test_ETH_AdjClosing', 'LSTM_Predictions',corr_ETH_LSTM))
# Out:
# correlation between test_ETH_AdjClosing and LSTM_Predictions is 0.931895

# %%
# 2.4.8 The Forecast Plot from all the four (4) models

plt.figure(figsize=(16,8))
plt.rcParams.update({'font.size':10})
plt.xticks(rotation=45)
ax = plt.axes()
ax.xaxis.set_major_locator(plt.MaxNLocator(20))
BTC_test['LSTM_Predictions'] = closing_priceL
plt.plot(BTC_train['BTC_AdjClosing'],label='train close')
plt.plot(BTC_test['BTC_AdjClosing'],label='BTC_test Close')
plt.plot(BTC_test['LSTM_Predictions'],label='LSTM_prediction')
plt.plot(BTC_test['ANN_Predictions'],label='ANN_predictions')
plt.plot(forecast['Prediction'],label='ARIMA_predictions')
plt.plot(BTC_test['MA_Predictions'],label='MA_Predictions')
plt.xlabel("Date")

plt.ylabel("Price") 
ax.grid(True)
plt.legend(loc='best')
plt.show()
# Out:
# C:\Users\xinye\AppData\Local\Temp/ipykernel_17100/2226596680.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   BTC_test['LSTM_Predictions'] = closing_priceL

# %% [markdown]
# ### Bitcoin Price Forecasting ###
#
# Evidently we will adopt the LSTM  as it births the best result for this assigment
#
# Machine learning and deep learning techniques can possibly facilitate the entire procedures of investigating enormous pieces of information, spotting critical examples and producing a solitary yield that explores investors towards a specific choice dependent on anticipated resource costs. We perceive that numerous Financial Enginners and Researchers are spending restless evenings attempting to improve the presentation of Machine Learning  and Deep learning models.
#
# Kindly note that crypto currency price can be influenced by numerous other profoundly interrelated elements. these elements include but not limited to;
#
# Government Policies,
#
# Exchange/ Trading Platform utillized for the Trade,
#
# Demand and supply for Bitcoin and/or Ethereum,
#
# Availability of other (Competting) Crypto-Currencies
#
# News on Common components like environmental change, dry season, tropical storms, floods, tremors and different elements like demonetization or merger/demerger of the associations could likewise influence the price of Bitcoin and/or Ethereum.
#
# Huge numbers of these variables can be hard to envision and may require extra instruments to appropriately estimate them
#
# We propose to open source our design to offer a chance to any  financial analysts or Financial Engineers with similar interest to  improve this work.

# %% [markdown]
# **3.DEVELOP A PROPOSED TRADING STRATEGY**

# %%
#3.1 calling the individual Cryptocurrencies 

BTC = pdr.get_data_yahoo(symbols='BTC-USD', start=datetime(2018, 1, 1), end=datetime(2019, 9, 1))
ETH = pdr.get_data_yahoo(symbols='ETH-USD', start=datetime(2018, 1, 1), end=datetime(2019, 9, 1))

pair= pd.concat([BTC['Adj Close'],ETH['Adj Close']], ignore_index=True,axis=1)

# %%
#3.1.1 Normalizing the datafrme  

def normalize_series(pair):
    #take tail to drop head NA
    return pair.pct_change(1).dropna()
pair_ret=normalize_series(pair)

#remove first row with NAs
pair_ret=pair_ret.tail(len(pair_ret)-1)
pair_ret.columns = ['BTC_RET','ETH_RET']
pair_ret['BTC_RET'].head()
# Out:
# Date
# 2018-01-03    0.014611
# 2018-01-04    0.026196
# 2018-01-05    0.117333
# 2018-01-06    0.005594
# 2018-01-07   -0.059873
# Name: BTC_RET, dtype: float64

# %%
#3.1.2 Normalizing and setting up cumulative returns in a  datafrme 
def normalize_and_accumulate_series(pair):
    #take tail to drop head NA
    return pair.pct_change(1).cumsum().dropna()
pair_cumret =normalize_and_accumulate_series(pair)


#remove first row with NAs
pair_cumret=pair_cumret.tail(len(pair_cumret)-1)
pair_cumret.columns = [ 'BTC_C.RET','ETH_C.RET']
pair_cumret['BTC_C.RET'].head()
# Out:
# Date
# 2018-01-03    0.111622
# 2018-01-04    0.137818
# 2018-01-05    0.255150
# 2018-01-06    0.260744
# 2018-01-07    0.200871
# Name: BTC_C.RET, dtype: float64

# %% [markdown]
# Then we split our Bitcoin Returns and Ethereum Returns into the training data set and the testing data set.
#
# After which we concatenated the tests into the tests data set.

# %%
#3.1.3 split into train and validation/testing

btc_R_train =  pair_ret['BTC_RET'][:488]
btc_R_test =   pair_ret['BTC_RET'][488:]
eth_R_train = pair_ret['ETH_RET'][:488]
eth_R_test =  pair_ret['ETH_RET'][488:]
tests= pd.concat([btc_R_test ,eth_R_test], ignore_index=False,axis=1)

tests
# Out:
#              BTC_RET   ETH_RET
# Date
# 2019-05-06 -0.008438  0.056301
# 2019-05-07  0.014390 -0.016533
# 2019-05-08  0.026238  0.006770
# 2019-05-09  0.032106 -0.003854
# 2019-05-10  0.033091  0.016756
# ...              ...       ...
# 2019-08-29 -0.025037 -0.025149
# 2019-08-30  0.009250 -0.004022
# 2019-08-31  0.003385  0.021529
# 2019-09-01  0.013219 -0.004873
# 2019-09-02  0.060339  0.039142
#
# [120 rows x 2 columns]

# %% [markdown]
# we decided to take a more techincal approach to the calculation of the spread, Z-score for the spread and then Rolling Spread z-score.
#
#
# $$
# S_{t} = y_{t} - \beta\ x_{t}
# $$
#
# $$
# S_{t} = spread\ at\ time\ t
# $$
#
# $$
# y_{t} = bitcoin\ price\ at\ time\ t
# $$
#
# $$
# \beta = zero\ intercept\ linear\ regression\ coefficient\ at\ time\ t\ also\ known\ as\ the\ hedge\
# $$
#
# $$
# x_{t} = Ethereum\ price\ at\ time\ t\
# $$
#
#
#
# $$
# {Z\left( S \right)}_{t} = \frac{S_{t} - \text{μS}_{t}}{\sigma S_{t}}
# $$
#
#
# $$
# {Z\left( S \right)}_{t} = Z - score\ of\ the\ spread\ in\ time\
# $$
#
# $$
# S_{t} = spread\ in\ time\
# $$
#
# $$
# \text{μS}_{t} = mean\ of\ the\ spread\ in\ time\
# $$
#
# $$
# \sigma S_{t} = standard\ deviation\ of\ the\ Spread\ in\ time\
# $$
#
#
#
# $$
# {Z\left( S \right)}_{(wind0w = 55)} = \frac{S_{t} - \text{μS}_{(wind0w = 55)}}{\sigma S_{(wind0w = 55)}}
# $$
#
# $$
# {Z\left( S \right)}_{(wind0w = 55)} = Z - score\ of\ the\ spread\ (with\ 55 - day\ window)
# $$
#
# $$
# S_{t} = spread\ in\ time\
# $$
#
# $$
# \text{μS}_{(wind0w = 55)} = mean\ of\ the\ spread\ (with\ 55 - day\ window)
# $$
#
# $$
# \sigma S_{(wind0w = 55)} = standard\ deviation\ of\ the\ Spread\ (with\ 55 - day\ window)\
# $$

# %%
#3.1.4 the Spread
pair_spread= btc_R_test - rg.OLS(btc_R_train, eth_R_train).fit().params[0] * eth_R_test
pair_spread
# Out:
# Date
# 2019-05-06   -0.042824
# 2019-05-07    0.024488
# 2019-05-08    0.022104
# 2019-05-09    0.034460
# 2019-05-10    0.022857
#                 ...
# 2019-08-29   -0.009677
# 2019-08-30    0.011707
# 2019-08-31   -0.009764
# 2019-09-01    0.016195
# 2019-09-02    0.036433
# Length: 120, dtype: float64

# %%
#3.2  calculating for beta (Hedge)

beta= rg.OLS(btc_R_train, eth_R_train).fit().params[0]
beta
# Out:
# 0.6107639240123753

# %%
#3.2.1 Pairs Spread plot

plt.figure(figsize=(16,8))
plt.rcParams.update({'font.size':10})
plt.xticks(rotation=45)
ax = plt.axes()
ax.xaxis.set_major_locator(plt.MaxNLocator(20))
plt.plot(pair_spread,color='green',label='BTC_ETH SPREAD')
plt.suptitle('BTC-ETH SPREAD')
ax.axhline(pair_spread.mean(), color='orange')
ax.grid(True)
plt.xlabel("Date")
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.legend(loc='best')
plt.show()

# %% [markdown]
# we begin this section with the check the ACF and the PACF of the Spread and then we checked for BTC-ETH Non-Stationary Prices. here we employ the Augmented Dickey-Fuller Stationary test

# %%
#3.2.2  ACF for pair Spread 

plot_acf(pair_spread, lags=50)
pyplot.show()

# %%
#3.2.3 PACF for pair Spread 

plot_pacf(pair_spread, lags=50)
pyplot.show()
# Out:
# C:\Users\xinye\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
#3.2.4  ACF for pair Spread^2 

plot_acf(pair_spread**2, lags=50)
pyplot.show()

# %%
#3.2.5 PACF for pair Spread^2 

plot_pacf(pair_spread**2, lags=50)
pyplot.show()
# Out:
# C:\Users\xinye\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
#3.2.6 Spread's Z-score Co-Integration Tests
print('== BTC-ETH Spread Augmented Dickey-Fuller Co-Integration Test ==')
print('')
print(at.ADF(pair_spread, trend='ct'))
print('')
print('== BTC-ETH new_spread Phillips-Perron Co-Integration Test ==')
print('')
print(at.PhillipsPerron(pair_spread, trend='ct', test_type='rho'))
print('')
# Out:
# == BTC-ETH Spread Augmented Dickey-Fuller Co-Integration Test ==
#
#    Augmented Dickey-Fuller Results
# =====================================
# Test Statistic                -10.821
# P-value                         0.000
# Lags                                0
# -------------------------------------
#
# Trend: Constant and Linear Time Trend
# Critical Values: -4.04 (1%), -3.45 (5%), -3.15 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.
#
# == BTC-ETH new_spread Phillips-Perron Co-Integration Test ==
#
#      Phillips-Perron Test (Z-rho)
# =====================================
# Test Statistic                -97.881
# P-value                         0.000
# Lags                               13
# -------------------------------------
#
# Trend: Constant and Linear Time Trend
# Critical Values: -27.49 (1%), -20.65 (5%), -17.48 (10%)
# Null Hypothesis: The process contains a unit root.
# Alternative Hypothesis: The process is weakly stationary.

# %%
#3.2.7 Spread Mean and Standard dev
spread_mean= pair_spread.mean()
spread_sd= pair_spread.std()

print('the mean of the spread is', spread_mean)
print('the Standard Dev of the Spread is',spread_sd)
# Out:
# the mean of the spread is 0.00481466142163123
# the Standard Dev of the Spread is 0.02927418650238553

# %%
#3.3   z_score=(pair_spread-spread_mean)/spread_sd
window= 55
pair_train= btc_R_test - rg.OLS(btc_R_train, eth_R_train).fit().params[0] * eth_R_test


# BTC_ETH Rolling Spread Z-Score Calculation


z_score = (pair_train - pair_train.rolling(window=window).mean()) / pair_train.rolling(window=window).std()
len(z_score)
# Out:
# 120

# %%
#3.3.1 Z-score Plot 

plt.figure(figsize=(16,8))
plt.rcParams.update({'font.size':10})
plt.xticks(rotation=45)
ax = plt.axes()
ax.xaxis.set_major_locator(plt.MaxNLocator(20))
plt.plot(z_score,color='blue',label='Z-score')
plt.suptitle('Z-score')
ax.axhline(z_score.mean(), color='orange')
ax.grid(True)
plt.xlabel("Date")
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.legend(loc='best')
plt.show()

# %%
#3.3.2 thresholds 

z_score.rolling(window=2).mean()
z_score.rolling(window=2).std()
up_th = (z_score.rolling(window=2).mean())+(z_score.rolling(window=2).std()*2) # upper threshold
lw_th = (z_score.rolling(window=2).mean())-(z_score.rolling(window=2).std()*2) # lower threshold

len(lw_th)
up_th.head(8)
# Out:
# Date
# 2019-05-06   NaN
# 2019-05-07   NaN
# 2019-05-08   NaN
# 2019-05-09   NaN
# 2019-05-10   NaN
# 2019-05-11   NaN
# 2019-05-12   NaN
# 2019-05-13   NaN
# dtype: float64

# %%
#3.3.3 Z-score Plot with threshold 

plt.figure(figsize=(16,8))
plt.rcParams.update({'font.size':10})
plt.xticks(rotation=45)
ax = plt.axes()
ax.xaxis.set_major_locator(plt.MaxNLocator(20))
plt.plot(z_score,color='blue',label='Z-score')
plt.plot(up_th,color='red',linestyle='--', label='upperLimit')
plt.plot(lw_th,color='brown',linestyle='--', label='lowerLimit')
plt.suptitle('Z-score')
ax.axhline(z_score.mean(), color='orange')
ax.grid(True)
plt.xlabel("Date")
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.legend(loc='best')
plt.show()

# %%
#3.3.4  getting equalent values of the returns, introducing return on returns to build signals


rbtc_ret= pair_ret['BTC_RET'].tail(120) # picking the last 120 transactions on Bitcoin  for our trading 
rbtc_ret

reth_ret= pair_ret['ETH_RET'].tail(120) # picking the last 120 transactions on Ethereum  for our trading 
reth_ret


#return on returns 
rrbtc=(pair_ret['BTC_RET'].pct_change(1).dropna()).pct_change(1).dropna().tail(120)#return on returns for bitcoin
rreth=(pair_ret['ETH_RET'].pct_change(1).dropna()).pct_change(1).dropna().tail(120)#return on returns for ethereum


trade_dir= pd.DataFrame(rbtc_ret)

trade_dir.insert(len(trade_dir.columns), 'rbtc_ret(-1)', rbtc_ret.shift(1))
trade_dir.insert(len(trade_dir.columns), 'rbtc_ret(-2)', rbtc_ret.shift(2))
trade_dir.insert(len(trade_dir.columns), 'reth_ret(-1)', reth_ret.shift(1))
trade_dir.insert(len(trade_dir.columns), 'reth_ret(-2)', reth_ret.shift(2))
trade_dir.insert(len(trade_dir.columns), 'rrbtc(-1)', rrbtc.shift(1))
trade_dir.insert(len(trade_dir.columns), 'rrbtc(-2)', rrbtc.shift(2))
trade_dir.insert(len(trade_dir.columns), 'rreth(-1)', rreth.shift(1))
trade_dir.insert(len(trade_dir.columns), 'rreth(-2)', rreth.shift(2))
trade_dirsig2 = 0.0
trade_dirsig2a = []

for i in trade_dir.index.values:
    if trade_dir.loc[i, 'rrbtc(-2)'] > (rreth[i]) and trade_dir.loc[i, 'rrbtc(-1)'] < (rreth[i]):
        trade_dirsig2 = 2
    elif trade_dir.loc[i, 'rrbtc(-2)'] < (rreth[i]) and trade_dir.loc[i, 'rrbtc(-1)'] > (rreth[i]):
        trade_dirsig2 = -2
    elif trade_dir.loc[i, 'rreth(-2)'] > (rrbtc[i]) and trade_dir.loc[i, 'rreth(-1)'] < (rrbtc[i]):
        trade_dirsig2 = 1
    elif trade_dir.loc[i, 'rreth(-2)'] < (rrbtc[i]) and trade_dir.loc[i, 'rreth(-1)'] > (rrbtc[i]):
        trade_dirsig2 = -1
    else:
        trade_dirsig2 = 0.0
    trade_dirsig2a.append(trade_dirsig2)
trade_dir.insert(len(trade_dir.columns), 'trade_dirsig2', trade_dirsig2a)

# %%
trade_dir['trade_dirsig2'].tail(80)
# Out:
# Date
# 2019-06-15    2.0
# 2019-06-16    0.0
# 2019-06-17    0.0
# 2019-06-18    1.0
# 2019-06-19    2.0
#              ...
# 2019-08-29    2.0
# 2019-08-30    0.0
# 2019-08-31   -1.0
# 2019-09-01    0.0
# 2019-09-02    1.0
# Name: trade_dirsig2, Length: 80, dtype: float64

# %%
tests
# Out:
#              BTC_RET   ETH_RET
# Date
# 2019-05-06 -0.008438  0.056301
# 2019-05-07  0.014390 -0.016533
# 2019-05-08  0.026238  0.006770
# 2019-05-09  0.032106 -0.003854
# 2019-05-10  0.033091  0.016756
# ...              ...       ...
# 2019-08-29 -0.025037 -0.025149
# 2019-08-30  0.009250 -0.004022
# 2019-08-31  0.003385  0.021529
# 2019-09-01  0.013219 -0.004873
# 2019-09-02  0.060339  0.039142
#
# [120 rows x 2 columns]

# %%
#3.3.5. BTC_ETH Trading Strategy Signals
tests.insert(len(tests.columns), 'z_score', z_score)
tests.insert(len(tests.columns), 'z_score(-1)', z_score.shift(1))
tests.insert(len(tests.columns), 'z_score(-2)', z_score.shift(2))
tests.insert(len(tests.columns), 'trade_dir', trade_dir['trade_dirsig2'])

ftestsig2 = 0.0
ftestsig2a = []

for i in tests.index.values:
    if tests.loc[i, 'z_score(-2)'] > (-1*up_th[i]) and tests.loc[i, 'z_score(-1)'] < (-1*up_th[i]):
        ftestsig2 = 1
    elif tests.loc[i, 'z_score(-2)'] < (-1*lw_th[i]) and tests.loc[i, 'z_score(-1)'] > (-1*lw_th[i]):
        ftestsig2 = -2
    elif tests.loc[i, 'z_score(-2)'] < (-1*up_th[i]) and tests.loc[i, 'z_score(-1)'] > (-1*up_th[i]):
        ftestsig2 = -1
    elif tests.loc[i, 'z_score(-2)'] > (-1*lw_th[i]) and tests.loc[i, 'z_score(-1)'] < (-1*lw_th[i]):
        ftestsig2 = 2
    elif tests.loc[i, 'z_score(-2)'] < up_th[i] and tests.loc[i, 'z_score(-1)'] > up_th[i]:
        ftestsig2 = -1
    elif tests.loc[i, 'z_score(-2)'] > up_th[i] and tests.loc[i, 'z_score(-1)'] < up_th[i]:
        ftestsig2 = 1
    elif tests.loc[i, 'z_score(-2)'] > lw_th[i] and tests.loc[i, 'z_score(-1)'] < lw_th[i]:
        ftestsig2 = 2
    elif tests.loc[i, 'z_score(-2)'] < lw_th[i] and tests.loc[i, 'z_score(-1)'] > lw_th[i]:
        ftestsig2 = -2
    elif tests.loc[i, 'trade_dir'] ==1:
        ftestsig2 = 2
    elif tests.loc[i, 'trade_dir'] == -1:
        ftestsig2 = -2
    elif tests.loc[i, 'trade_dir'] == 2:
        ftestsig2 = 1
    elif tests.loc[i, 'trade_dir']== -2:
        ftestsig2 = -1
    else:
        ftestsig2 = 0.0
    ftestsig2a.append(ftestsig2)
tests.insert(len(tests.columns), 'ftestsig2', ftestsig2a)



print('== BTC_ETH Trading Strategy Signals ==')
print('')
print(tests.loc['2019-05-13':, ['z_score', 'ftestsig2']])
print('')
# Out:
# == BTC_ETH Trading Strategy Signals ==
#
#              z_score  ftestsig2
# Date
# 2019-05-13       NaN        1.0
# 2019-05-14       NaN       -1.0
# 2019-05-15       NaN        1.0
# 2019-05-16       NaN        0.0
# 2019-05-17       NaN        2.0
# ...              ...        ...
# 2019-08-29 -0.561189       -1.0
# 2019-08-30  0.358140        0.0
# 2019-08-31 -0.567479       -2.0
# 2019-09-01  0.609215        0.0
# 2019-09-02  1.511230       -2.0
#
# [113 rows x 2 columns]

# %%
#3.3.6 testing our trading logic
(tests.loc['2019-05-13':, ['z_score', 'ftestsig2']]).tail(15)
# Out:
#              z_score  ftestsig2
# Date
# 2019-08-19  0.743265        2.0
# 2019-08-20  0.081949       -2.0
# 2019-08-21 -1.064738        0.0
# 2019-08-22 -0.611572        1.0
# 2019-08-23  0.481960        0.0
# 2019-08-24 -0.633691       -1.0
# 2019-08-25  0.283208       -2.0
# 2019-08-26  0.442165       -2.0
# 2019-08-27 -0.662152       -1.0
# 2019-08-28 -0.046509        1.0
# 2019-08-29 -0.561189       -1.0
# 2019-08-30  0.358140        0.0
# 2019-08-31 -0.567479       -2.0
# 2019-09-01  0.609215        0.0
# 2019-09-02  1.511230       -2.0

# %%
tests.insert(len(tests.columns), 'rbtc_ret', rbtc_ret)
tests.insert(len(tests.columns), 'reth_ret', reth_ret)



tests
# Out:
#              BTC_RET   ETH_RET   z_score  z_score(-1)  z_score(-2)  trade_dir  \
# Date
# 2019-05-06 -0.008438  0.056301       NaN          NaN          NaN        0.0
# 2019-05-07  0.014390 -0.016533       NaN          NaN          NaN        0.0
# 2019-05-08  0.026238  0.006770       NaN          NaN          NaN        0.0
# 2019-05-09  0.032106 -0.003854       NaN          NaN          NaN       -1.0
# 2019-05-10  0.033091  0.016756       NaN          NaN          NaN        0.0
# ...              ...       ...       ...          ...          ...        ...
# 2019-08-29 -0.025037 -0.025149 -0.561189    -0.046509    -0.662152        2.0
# 2019-08-30  0.009250 -0.004022  0.358140    -0.561189    -0.046509        0.0
# 2019-08-31  0.003385  0.021529 -0.567479     0.358140    -0.561189       -1.0
# 2019-09-01  0.013219 -0.004873  0.609215    -0.567479     0.358140        0.0
# 2019-09-02  0.060339  0.039142  1.511230     0.609215    -0.567479        1.0
#
#             ftestsig2  rbtc_ret  reth_ret
# Date
# 2019-05-06        0.0 -0.008438  0.056301
# 2019-05-07        0.0  0.014390 -0.016533
# 2019-05-08        0.0  0.026238  0.006770
# 2019-05-09       -2.0  0.032106 -0.003854
# 2019-05-10        0.0  0.033091  0.016756
# ...               ...       ...       ...
# 2019-08-29       -1.0 -0.025037 -0.025149
# 2019-08-30        0.0  0.009250 -0.004022
# 2019-08-31       -2.0  0.003385  0.021529
# 2019-09-01        0.0  0.013219 -0.004873
# 2019-09-02       -2.0  0.060339  0.039142
#
# [120 rows x 9 columns]

# %%
pair
# Out:
#                        0           1
# Date
# 2018-01-01  13657.200195  772.640991
# 2018-01-02  14982.099609  884.443970
# 2018-01-03  15201.000000  962.719971
# 2018-01-04  15599.200195  980.921997
# 2018-01-05  17429.500000  997.719971
# ...                  ...         ...
# 2019-08-29   9510.200195  169.516739
# 2019-08-30   9598.173828  168.834869
# 2019-08-31   9630.664062  172.469788
# 2019-09-01   9757.970703  171.629425
# 2019-09-02  10346.760742  178.347351
#
# [610 rows x 2 columns]

# %%
#3.3.6 Trading Strategy Signals, without commission/exchange fee

port_out = 0.0
port_outa = []

for i in tests.index.values:
    if tests.loc[i, 'ftestsig2'] == -2:
        port_out = tests.loc[i, 'rbtc_ret']
    elif tests.loc[i, 'ftestsig2'] == -1:
        port_out = tests.loc[i, 'reth_ret']
    elif tests.loc[i, 'ftestsig2'] == 2:
        port_out = tests.loc[i, 'rbtc_ret']
    elif tests.loc[i, 'ftestsig2'] == 1:
        port_out = tests.loc[i, 'reth_ret']
    else:
        port_out = tests.loc[i, 'rbtc_ret']
    port_outa.append(port_out)
tests.insert(len(tests.columns), 'port_out', port_outa)
tests = tests.fillna(method='ffill')


port_outc = 0.0
port_outca = []
# with 5% commission 
com =0.05

for i in tests.index.values:
    if tests.loc[i, 'ftestsig2'] == -2:
        port_outc = ((tests.loc[i, 'rbtc_ret']) -abs(com*((tests.loc[i, 'rbtc_ret'])-(tests.loc[i, 'reth_ret']))))
    elif tests.loc[i, 'ftestsig2'] == -1:
        port_outc = ((tests.loc[i, 'reth_ret']) -abs(com*((tests.loc[i, 'rbtc_ret'])-(tests.loc[i, 'reth_ret']))))
    elif tests.loc[i, 'ftestsig2'] == 2:
        port_outc = ((tests.loc[i, 'rbtc_ret']) -abs(com*((tests.loc[i, 'rbtc_ret'])-(tests.loc[i, 'reth_ret']))))
    elif tests.loc[i, 'ftestsig2'] == 1:
        port_outc = ((tests.loc[i, 'reth_ret']) -abs(com*((tests.loc[i, 'rbtc_ret'])-(tests.loc[i, 'reth_ret']))))
    else:
        port_outc = ((tests.loc[i, 'rbtc_ret']) -abs(com*((tests.loc[i, 'rbtc_ret'])-(tests.loc[i, 'reth_ret']))))
    port_outca.append(port_outc)
tests.insert(len(tests.columns), 'port_outc', port_outca)
tests = tests.fillna(method='ffill')


print('== BTC_ETH Trading Strategy Position ==')
print('')
print(tests.loc['2019-05-13':, ['z_score', 'ftestsig2', 'port_out', 'port_outc']])
print('')
# Out:
# == BTC_ETH Trading Strategy Position ==
#
#              z_score  ftestsig2  port_out  port_outc
# Date
# 2019-05-13       NaN        1.0  0.050826   0.047325
# 2019-05-14       NaN       -1.0  0.103138   0.099129
# 2019-05-15       NaN        1.0  0.138175   0.132584
# 2019-05-16       NaN        0.0 -0.039031  -0.044393
# 2019-05-17       NaN        2.0 -0.068614  -0.069017
# ...              ...        ...       ...        ...
# 2019-08-29 -0.561189       -1.0 -0.025149  -0.025155
# 2019-08-30  0.358140        0.0  0.009250   0.008587
# 2019-08-31 -0.567479       -2.0  0.003385   0.002478
# 2019-09-01  0.609215        0.0  0.013219   0.012314
# 2019-09-02  1.511230       -2.0  0.060339   0.059280
#
# [113 rows x 4 columns]

# %%
trade_dir
# Out:
#              BTC_RET  rbtc_ret(-1)  rbtc_ret(-2)  reth_ret(-1)  reth_ret(-2)  \
# Date
# 2019-05-06 -0.008438           NaN           NaN           NaN           NaN
# 2019-05-07  0.014390     -0.008438           NaN      0.056301           NaN
# 2019-05-08  0.026238      0.014390     -0.008438     -0.016533      0.056301
# 2019-05-09  0.032106      0.026238      0.014390      0.006770     -0.016533
# 2019-05-10  0.033091      0.032106      0.026238     -0.003854      0.006770
# ...              ...           ...           ...           ...           ...
# 2019-08-29 -0.025037     -0.042323     -0.017869     -0.072669     -0.007478
# 2019-08-30  0.009250     -0.025037     -0.042323     -0.025149     -0.072669
# 2019-08-31  0.003385      0.009250     -0.025037     -0.004022     -0.025149
# 2019-09-01  0.013219      0.003385      0.009250      0.021529     -0.004022
# 2019-09-02  0.060339      0.013219      0.003385     -0.004873      0.021529
#
#             rrbtc(-1)  rrbtc(-2)  rreth(-1)  rreth(-2)  trade_dirsig2
# Date
# 2019-05-06        NaN        NaN        NaN        NaN            0.0
# 2019-05-07  -1.248762        NaN  19.047299        NaN            0.0
# 2019-05-08  -7.981147  -1.248762  -0.924064  19.047299            0.0
# 2019-05-09  -1.304357  -7.981147   0.089515  -0.924064           -1.0
# 2019-05-10  -0.728421  -1.304357   0.113413   0.089515            0.0
# ...               ...        ...        ...        ...            ...
# 2019-08-29  -1.768838  -0.849878  -6.222342   0.127654            2.0
# 2019-08-30  -1.298458  -1.768838  -1.075005  -6.222342            0.0
# 2019-08-31   2.353071  -1.298458   0.284651  -1.075005           -1.0
# 2019-09-01  -0.536998   2.353071   6.561784   0.284651            0.0
# 2019-09-02  -5.581669  -0.536998  -0.806950   6.561784            1.0
#
# [120 rows x 10 columns]

# %%
tests['port_out'].head(15)
# Out:
# Date
# 2019-05-06   -0.008438
# 2019-05-07    0.014390
# 2019-05-08    0.026238
# 2019-05-09    0.032106
# 2019-05-10    0.033091
# 2019-05-11    0.129478
# 2019-05-12   -0.032256
# 2019-05-13    0.050826
# 2019-05-14    0.103138
# 2019-05-15    0.138175
# 2019-05-16   -0.039031
# 2019-05-17   -0.068614
# 2019-05-18   -0.009898
# 2019-05-19    0.127418
# 2019-05-20   -0.036081
# Name: port_out, dtype: float64

# %%
tests
# Out:
#              BTC_RET   ETH_RET   z_score  z_score(-1)  z_score(-2)  trade_dir  \
# Date
# 2019-05-06 -0.008438  0.056301       NaN          NaN          NaN        0.0
# 2019-05-07  0.014390 -0.016533       NaN          NaN          NaN        0.0
# 2019-05-08  0.026238  0.006770       NaN          NaN          NaN        0.0
# 2019-05-09  0.032106 -0.003854       NaN          NaN          NaN       -1.0
# 2019-05-10  0.033091  0.016756       NaN          NaN          NaN        0.0
# ...              ...       ...       ...          ...          ...        ...
# 2019-08-29 -0.025037 -0.025149 -0.561189    -0.046509    -0.662152        2.0
# 2019-08-30  0.009250 -0.004022  0.358140    -0.561189    -0.046509        0.0
# 2019-08-31  0.003385  0.021529 -0.567479     0.358140    -0.561189       -1.0
# 2019-09-01  0.013219 -0.004873  0.609215    -0.567479     0.358140        0.0
# 2019-09-02  0.060339  0.039142  1.511230     0.609215    -0.567479        1.0
#
#             ftestsig2  rbtc_ret  reth_ret  port_out  port_outc
# Date
# 2019-05-06        0.0 -0.008438  0.056301 -0.008438  -0.011674
# 2019-05-07        0.0  0.014390 -0.016533  0.014390   0.012843
# 2019-05-08        0.0  0.026238  0.006770  0.026238   0.025265
# 2019-05-09       -2.0  0.032106 -0.003854  0.032106   0.030308
# 2019-05-10        0.0  0.033091  0.016756  0.033091   0.032274
# ...               ...       ...       ...       ...        ...
# 2019-08-29       -1.0 -0.025037 -0.025149 -0.025149  -0.025155
# 2019-08-30        0.0  0.009250 -0.004022  0.009250   0.008587
# 2019-08-31       -2.0  0.003385  0.021529  0.003385   0.002478
# 2019-09-01        0.0  0.013219 -0.004873  0.013219   0.012314
# 2019-09-02       -2.0  0.060339  0.039142  0.060339   0.059280
#
# [120 rows x 11 columns]

# %%
#3.4 Output of all 4 Senarios

pt_out = np.exp(np.log1p(tests['port_out']).cumsum())- 1 # pair trading return 
pt_out

pt_outc = np.exp(np.log1p(tests['port_outc']).cumsum())- 1 # pair trading with 5% commision  return 
pt_outc

bh_btc= np.exp(np.log1p(tests['rbtc_ret']).cumsum())- 1 # buy and Hold Bitcoin 
bh_btc

bh_eth= np.exp(np.log1p(tests['reth_ret']).cumsum())- 1 # buy and Hold Ethereum
        
bh_eth
# Out:
# Date
# 2019-05-06    0.056301
# 2019-05-07    0.038837
# 2019-05-08    0.045870
# 2019-05-09    0.041839
# 2019-05-10    0.059296
#                 ...
# 2019-08-29    0.037112
# 2019-08-30    0.032941
# 2019-08-31    0.055179
# 2019-09-01    0.050038
# 2019-09-02    0.091139
# Name: reth_ret, Length: 120, dtype: float64

# %%
#3.4.1 portfolio returns Chart

plt.figure(figsize=(16,8))
plt.rcParams.update({'font.size':10})
plt.xticks(rotation=45)
ax = plt.axes()
ax.xaxis.set_major_locator(plt.MaxNLocator(20))
plt.plot(pt_out, label='Cumulative return on P-Trading Strategy portfolio')
plt.plot(pt_outc, label='Cumulative return on P-Trading Strategy_+5%Cm')
plt.plot(bh_btc, label='Cumulative return on Buy and Hold Bitcoin')
plt.plot(bh_eth, label='Cumulative return on Buy and Hold Ethereum')
plt.title('BTC_ETH Trading Strategy Cumulative Returns')
plt.xlabel("Date")
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.suptitle('BTC_ETH Portfolio Cumulative Returns  (120 days ( 55-days rolling window))')
ax.legend(loc='best')
ax.grid(True)

plt.show()

# %%
#3.4.2. BTC_ETH Strategy Performance Summary
results2 = [{'0': 'Test-Period:', '1': 'P-Trading Strategy', '2': 'P-Trading Strategy_+5%Cm', '3': 'Buy&Hold Bitcoin', '4': 'Buy&Hold Ethereum'},
        {'0': 'Return', '1': np.round(pt_out[-1], 4),
         '2':np.round(pt_outc[-1], 4),
         '3': np.round(bh_btc[-1], 4),
         '4': np.round(bh_eth[-1], 4)},
        {'0': 'Standard Deviation', '1': np.round(np.std(pt_out) , 4),
         '2': np.round(np.std(pt_outc), 4),
         '3': np.round(np.std(bh_btc), 4),
         '4': np.round(np.std(bh_eth), 4)},
        {'0': 'Sharpe Ratio (Rf=0%)', '1': np.round(pt_out[-1] / (np.std(pt_out)), 4),
         '2': np.round(pt_outc[-1] / (np.std(pt_outc) ), 4),
         '3': np.round(bh_btc[-1] / (np.std(bh_btc)), 4),
         '4': np.round(bh_eth[-1] / (np.std(bh_eth) ), 4)}]
table2 = pd.DataFrame(results2)
print('')
print('== BTC_ETH Strategy Performance Summary ==')
print('')
print(table2)
# Out:
# == BTC_ETH Strategy Performance Summary ==
#
#                       0                   1                         2  \
# 0          Test-Period:  P-Trading Strategy  P-Trading Strategy_+5%Cm
# 1                Return              1.0422                    0.7971
# 2    Standard Deviation              0.3144                    0.2613
# 3  Sharpe Ratio (Rf=0%)              3.3145                    3.0501
#
#                   3                  4
# 0  Buy&Hold Bitcoin  Buy&Hold Ethereum
# 1            0.7852             0.0911
# 2             0.275              0.256
# 3            2.8557              0.356

# %%
#3.4.2. Analysing Profitabiliy of the Strategy

Max_ret=pd.Series.max(tests['port_out'], axis=None, skipna=None, level=None, numeric_only=None) 
Min_ret=pd.Series.min(tests['port_out'], axis=None, skipna=None, level=None, numeric_only=None)
Min_cret=pd.Series.min(pt_out, axis=None, skipna=None, level=None, numeric_only=None)

Min_ret_count=len(tests['port_out'].loc[(tests['port_out'] < 0)]) 
Max_ret_count =len(tests['port_out'].loc[(tests['port_out'] > 0)]) 
Optimal_trade=((Max_ret_count)/(len(tests['port_out'])))*100

print('the Maximum Return per time for this portfolio is',(np.round(Max_ret,2)))
print('the Minimum Return per time for this portfolio is',(np.round(Min_ret,2)))
print('the Minimum Cumulative Returns  for this portfolio is',(np.round(Min_cret,2)))
print('the Profitability of the paired Trading Strategy is',(np.round(Optimal_trade,2)),'%')
print('trade with the consideration of the hedge ',(np.round(beta,2)),'%','beta','that is 100 value avaliable to bitcoin and ',(np.round(beta*100,0)),' to Ethereum')
# Out:
# the Maximum Return per time for this portfolio is 0.14
# the Minimum Return per time for this portfolio is -0.16
# the Minimum Cumulative Returns  for this portfolio is -0.01
# the Profitability of the paired Trading Strategy is 61.67 %
# trade with the consideration of the hedge  0.61 % beta that is 100 value avaliable to bitcoin and  61.0  to Ethereum
